# %%
from datetime import datetime
start_time = datetime.now()
import pandas as pd
import csv
import os
path = "/Users/michaelwymbs/Documents/wahal"
os.chdir(path)
df1 = pd.read_csv('df1.csv')
df1['familyname']=""
mfev=df1.query(' dbname=="mfev"')
mfev1 = mfev
mf=df1.query(' dbname=="mf"')
mf1 = mf
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
fundf11 = pd.read_csv('fundname1.csv') #Query file
a=mf1['range']
b=list(a)
aa=mf1['String']
bb=list(aa)
dict1 = {}
dict2 = {}
for i in range(0,len(b)):
    dict1[b[i]]=bb[i]
    dict2[b[i]]=[]

listdict = []

for i in range(0,fundf11.shape[0]):
    if i % 1000 ==0:
        print datetime.now() 
    for j in range(0,len(b)):
        if fundf11.loc[i,'String'] in dict1[b[j]]:
            listdict.append((b[j], fundf11.loc[i,'mgmt_cd']))
# Out:
# 2015-11-14 17:01:03.313632
# 2015-11-14 18:44:00.263445
# 2015-11-14 20:20:45.664953

# %%
from collections import defaultdict
d = defaultdict(list)
for key, permno in listdict:
    d[key].append(permno)
for i in d.keys():
    d[i] = list(set(d.get(i)))
dictionarymf = pd.DataFrame({'range' : d.keys() , 'PERMNO' : d.values() })
for i in range(0,dictionarymf.shape[0]):
    mf1.familyname[int(dictionarymf.range[i])]=",".join(dictionarymf.PERMNO[i])
mf1.familyname.value_counts()
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3066: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# AFD                2681
# VAN                2498
# FID                1249
#                    1050
# PRI                 890
# PIM                 452
# BLI,BLK             378
# WFB,EII             312
# MOR,JPM             290
# PRG                 214
# MFS                 203
# OPP                 179
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8eea1152ebd3> in <module>()
# ----> 1 listdict.keys
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
# Out:
# [(42663.0, 'YAC'),
#  (43588.0, 'YAC'),
#  (43609.0, 'YAC'),
#  (44105.0, 'YAC'),
#  (44106.0, 'YAC'),
#  (53373.0, 'YAC'),
#  (60530.0, 'YAC'),
#  (6350.0, 'WTA'),
#  (6351.0, 'WTA'),
#  (11287.0, 'MTB'),
#  (43491.0, 'MTB'),
#  (11287.0, 'WIL'),
#  (43491.0, 'WIL'),
#  (4682.0, 'BLW'),
#  (5769.0, 'BLW'),
#  (11064.0, 'BLW'),
#  (13955.0, 'BLW'),
#  (14306.0, 'BLW'),
#  (24088.0, 'BLW'),
#  (25465.0, 'BLW'),
#  (41878.0, 'BLW'),
#  (44400.0, 'BLW'),
#  (45259.0, 'BLW'),
#  (50877.0, 'BLW'),
#  (51194.0, 'BLW'),
#  (52223.0, 'BLW'),
#  (54338.0, 'BLW'),
#  (63077.0, 'BLW'),
#  (4696.0, 'BLW'),
#  (52235.0, 'BLW'),
#  (8435.0, 'WMC'),
#  (26968.0, 'WTP'),
#  (17546.0, 'WCF'),
#  (25345.0, 'WCF'),
#  (51461.0, 'WCF'),
#  (56424.0, 'WCF'),
#  (59221.0, 'WCF'),
#  (595.0, 'WFB'),
#  (774.0, 'WFB'),
#  (1007.0, 'WFB'),
#  (2998.0, 'WFB'),
#  (2999.0, 'WFB'),
#  (3000.0, 'WFB'),
#  (3001.0, 'WFB'),
#  (3002.0, 'WFB'),
#  (3003.0, 'WFB'),
#  (3967.0, 'WFB'),
#  (4449.0, 'WFB'),
# ...

# %%
mf1.familyname.value_counts()
# Out:
# AFD                2681
# VAN                2498
# FID                1249
#                    1050
# PRI                 890
# PIM                 452
# BLI,BLK             378
# WFB,EII             312
# MOR,JPM             290
# PRG                 214
# MFS                 203
# OPP                 179
# MBI,UMB             178
# ACI                 162
# INV,IVS             136
# DFA                 134
# PRU,PRD             128
# DNC                 122
# ING,OPP              96
# FSA,FRA              92
# RSS                  86
# GSC                  81
# FED                  78
# ING,MAN              75
# JAN                  75
# RSC                  73
# JHA,JHI,HHF          72
# FRA                  70
# VAN,FID              69
# CSW                  67
#                    ...
# AFD,ISHARES           1
# JDR                   1
# PUT,RSC               1
# MNS,MIW,ING           1
# WEI                   1
# HER,SSC               1
# AFD,AAL               1
# ...

# %%
for i in range(0,fundf11.shape[0]):
    if i % 10 ==0:
        print datetime.now() 
    for j in range(0,len(b)):
        if fundf11.loc[i,'String'] in dict1[b[j]]:
            listdict.append((b[j], fundf11.loc[i,'mgmt_cd']))
# Out:
# 2015-10-22 11:58:25.342242
# 2015-10-22 11:59:38.945514
# 2015-10-22 12:00:42.123061
# 2015-10-22 12:01:47.416787
# 2015-10-22 12:02:51.076703
# 2015-10-22 12:03:55.347212
# 2015-10-22 12:04:59.549271
# 2015-10-22 12:06:03.486166
# 2015-10-22 12:07:10.892079
# 2015-10-22 12:08:14.109246
# 2015-10-22 12:09:18.060987
# 2015-10-22 12:10:31.622604
# 2015-10-22 12:11:39.808795
# 2015-10-22 12:12:46.801625
# 2015-10-22 12:13:54.553193
# 2015-10-22 12:15:02.088523
# 2015-10-22 12:16:08.736140
# 2015-10-22 12:17:15.767391
# 2015-10-22 12:18:22.293103
# 2015-10-22 12:19:28.873850
# 2015-10-22 12:20:35.651804
# 2015-10-22 12:21:42.086600
# 2015-10-22 12:22:48.262338
# 2015-10-22 12:23:54.844090
# 2015-10-22 12:25:00.027311
# 2015-10-22 12:26:02.244789
# 2015-10-22 12:27:11.296734
# 2015-10-22 12:28:14.699520
# 2015-10-22 12:29:18.193146
# 2015-10-22 12:30:20.494338
# 2015-10-22 12:31:22.663117
# 2015-10-22 12:32:27.944135
# 2015-10-22 12:33:32.173059
# 2015-10-22 12:34:34.350118
# ...

# %%
from collections import defaultdict
d = defaultdict(list)
for key, permno in listdict:
    d[key].append(permno)
for i in d.keys():
    d[i] = list(set(d.get(i)))
dictionarymf = pd.DataFrame({'range' : d.keys() , 'PERMNO' : d.values() })

# %%
for i in range(0,dictionarymf.shape[0]):
    mf2.familyname[int(dictionarymf.range[i])]=",".join(dictionarymf.PERMNO[i])

# %%
afd=mf2.query(' familyname=="AFD"')
afd.String
# Out:
# 118                  AF 2015 TARGET DATE RETIREMENT FUND
# 119                  AF 2020 TARGET DATE RETIREMENT FUND
# 120                  AF 2025 TARGET DATE RETIREMENT FUND
# 121                  AF 2030 TARGET DATE RETIREMENT FUND
# 122                  AF 2035 TARGET DATE RETIREMENT FUND
# 123                  AF 2040 TARGET DATE RETIREMENT FUND
# 124                  AF 2045 TARGET DATE RETIREMENT FUND
# 125                  AF 2050 TARGET DATE RETIREMENT FUND
# 244                           AF TARGET DATE RET 2020 R3
# 253              AMERICAN FUNDS 2030 TARGET DATE FUND R3
# 256                          AF 2045 TARGET DATE FUND R3
# 257                          AF 2040 TARGET DATE FUND R3
# 258                          AF 2055 TARGET DATE FUND R3
# 488      MUTUAL FUNDS  AMERICAN FUNDS EURO PACIFIC GROW...
# 535                   AM FDS CAP WLD GR & INC  MUTUAL FUND
# 539                 AM FDS EUROPACIFIC GROWTH  MUTUAL FUND
# ...

# %%
fundf = pd.read_csv('fundname.csv')
fundf3 = fundf.drop(['caldt',],1)
fundf3=fundf3.drop_duplicates()
fundf3=fundf3.dropna()
fundf3.to_csv('crspfundno.csv')

#q = 'len(familyname)>3'
#fid=mf2.query(' dbname=="mf"')

# %%
mf2[mf2.familyname.str.len() > 11]
# Out:
#        Unnamed: 0                          ACK ID Party-in-Interest  \
# 737           737  20140718094344P030013496559001               NaN
# 778           778  20140724111937P040017569871001               NaN
# 782           782  20140724111937P040017569871001               NaN
# 847           847  20140728143512P030019623711001                 *
# 1043         1043  20140731130209P030065620503001               NaN
# 1048         1048  20140731130209P030065620503001               NaN
# 1054         1054  20140731130209P030065620503001               NaN
# 1187         1187  20140811095025P030027280079001               NaN
# 1188         1188  20140811095025P030027280079001               NaN
# 1189         1189  20140811095025P030027280079001               NaN
# 1190         1190  20140811095025P030027280079001               NaN
# 1191         1191  20140811095025P030027280079001               NaN
# 1192         1192  20140811095025P030027280079001               NaN
# ...

# %%
fundnos = pd.read_csv('fundnos.csv')
fundnos = fundnos.drop(['caldt',],1)
fundnos=fundnos.drop_duplicates()
fundnos=fundnos.dropna()
fundnos.to_csv('crspfundnos.csv')

# %%
mf1 = mf2.query(' familyname == ""')
fundf11 = pd.read_csv('fundname1.csv')
a=mf1['range']
b=list(a)
aa=mf1['String']
bb=list(aa)
dict1 = {}
dict2 = {}
for i in range(0,len(b)):
    dict1[b[i]]=bb[i]
    dict2[b[i]]=[]

listdict = []

for i in range(0,fundf11.shape[0]):
    if i % 100 ==0:
        print datetime.now() 
    for j in range(0,len(b)):
        if fundf11.loc[i,'String'] in dict1[b[j]]:
            listdict.append((b[j], fundf11.loc[i,'mgmt_cd']))
mf1.to_csv('familymissing.csv')
# Out:
# 2015-11-07 15:14:16.043193
# 2015-11-07 15:15:01.571633
# 2015-11-07 15:15:42.183679
# 2015-11-07 15:16:22.379894
# 2015-11-07 15:17:02.139130
# 2015-11-07 15:17:43.393476
# 2015-11-07 15:18:22.083673
# 2015-11-07 15:19:01.601953
# 2015-11-07 15:19:46.452006
# 2015-11-07 15:20:25.366253
# 2015-11-07 15:21:07.132327
# 2015-11-07 15:22:23.370039
# 2015-11-07 15:23:15.696114
# 2015-11-07 15:23:59.100365
# 2015-11-07 15:24:40.641731
# 2015-11-07 15:25:21.179483
# 2015-11-07 15:26:01.366550
# 2015-11-07 15:26:42.862976
# 2015-11-07 15:27:23.653263
# 2015-11-07 15:28:05.544877
# 2015-11-07 15:28:46.841263
# 2015-11-07 15:29:27.513652

# %%
API=fundnos.query('mgmt_cd=="API"')
MCB=fundnos.query('mgmt_cd=="MCB"')
UAM=fundnos.query('mgmt_cd=="UAM"')
DRY=fundnos.query('mgmt_cd=="DRY"')
MGC=fundnos.query('mgmt_cd=="MGC"')
DLB=fundnos.query('mgmt_cd=="DLB"')
OPP=fundnos.query('mgmt_cd=="OPP"')
NAS=fundnos.query('mgmt_cd=="NAS"')
PNR=fundnos.query('mgmt_cd=="PNR"')
ARN=fundnos.query('mgmt_cd=="ARN"')
PLG=fundnos.query('mgmt_cd=="PLG"')
PRG=fundnos.query('mgmt_cd=="PRG"')
SBS=fundnos.query('mgmt_cd=="SBS"')
WMS=fundnos.query('mgmt_cd=="WMS"')
SSR=fundnos.query('mgmt_cd=="SSR"')
WIS=fundnos.query('mgmt_cd=="WIS"')
CSG=fundnos.query('mgmt_cd=="CSG"')
AAL=fundnos.query('mgmt_cd=="AAL"')
ARP=fundnos.query('mgmt_cd=="ARP"')
SBC=fundnos.query('mgmt_cd=="SBC"')
ABF=fundnos.query('mgmt_cd=="ABF"')
ABN=fundnos.query('mgmt_cd=="ABN"')
ASM=fundnos.query('mgmt_cd=="ASM"')
CTT=fundnos.query('mgmt_cd=="CTT"')
MHG=fundnos.query('mgmt_cd=="MHG"')
JNB=fundnos.query('mgmt_cd=="JNB"')
AFF=fundnos.query('mgmt_cd=="AFF"')
FBR=fundnos.query('mgmt_cd=="FBR"')
HEN=fundnos.query('mgmt_cd=="HEN"')
HNF=fundnos.query('mgmt_cd=="HNF"')
SAM=fundnos.query('mgmt_cd=="SAM"')
AIM=fundnos.query('mgmt_cd=="AIM"')
IVS=fundnos.query('mgmt_cd=="IVS"')
AIN=fundnos.query('mgmt_cd=="AIN"')
AIP=fundnos.query('mgmt_cd=="AIP"')
AXP=fundnos.query('mgmt_cd=="AXP"')
IDS=fundnos.query('mgmt_cd=="IDS"')
ENT=fundnos.query('mgmt_cd=="ENT"')
AXA=fundnos.query('mgmt_cd=="AXA"')
END=fundnos.query('mgmt_cd=="END"')
EQL=fundnos.query('mgmt_cd=="EQL"')
ACS=fundnos.query('mgmt_cd=="ACS"')
WEB=fundnos.query('mgmt_cd=="WEB"')
PNN=fundnos.query('mgmt_cd=="PNN"')
PRF=fundnos.query('mgmt_cd=="PRF"')
PFS=fundnos.query('mgmt_cd=="PFS"')
FSI=fundnos.query('mgmt_cd=="FSI"')
DWI=fundnos.query('mgmt_cd=="DWI"')
MST=fundnos.query('mgmt_cd=="MST"')
ACT=fundnos.query('mgmt_cd=="ACT"')
APS=fundnos.query('mgmt_cd=="APS"')
LEN=fundnos.query('mgmt_cd=="LEN"')
ARM=fundnos.query('mgmt_cd=="ARM"')
ADV=fundnos.query('mgmt_cd=="ADV"')
ADS=fundnos.query('mgmt_cd=="ADS"')
CBR=fundnos.query('mgmt_cd=="CBR"')
CCA=fundnos.query('mgmt_cd=="CCA"')
AII=fundnos.query('mgmt_cd=="AII"')
ACD=fundnos.query('mgmt_cd=="ACD"')
TSW=fundnos.query('mgmt_cd=="TSW"')
AEG=fundnos.query('mgmt_cd=="AEG"')
MCK=fundnos.query('mgmt_cd=="MCK"')
RHJ=fundnos.query('mgmt_cd=="RHJ"')
ICM=fundnos.query('mgmt_cd=="ICM"')
FMA=fundnos.query('mgmt_cd=="FMA"')
JHA=fundnos.query('mgmt_cd=="JHA"')
CHG=fundnos.query('mgmt_cd=="CHG"')
NFS=fundnos.query('mgmt_cd=="NFS"')
SIR=fundnos.query('mgmt_cd=="SIR"')
SYN=fundnos.query('mgmt_cd=="SYN"')
SNT=fundnos.query('mgmt_cd=="SNT"')
PAM=fundnos.query('mgmt_cd=="PAM"')
TOE=fundnos.query('mgmt_cd=="TOE"')
STL=fundnos.query('mgmt_cd=="STL"')
HGK=fundnos.query('mgmt_cd=="HGK"')
LSV=fundnos.query('mgmt_cd=="LSV"')
FMN=fundnos.query('mgmt_cd=="FMN"')
AIG=fundnos.query('mgmt_cd=="AIG"')
CMI=fundnos.query('mgmt_cd=="CMI"')
WMC=fundnos.query('mgmt_cd=="WMC"')
UAP=fundnos.query('mgmt_cd=="UAP"')
EMC=fundnos.query('mgmt_cd=="EMC"')
HAV=fundnos.query('mgmt_cd=="HAV"')
CBI=fundnos.query('mgmt_cd=="CBI"')
BGB=fundnos.query('mgmt_cd=="BGB"')
CLS=fundnos.query('mgmt_cd=="CLS"')
ORB=fundnos.query('mgmt_cd=="ORB"')
AOF=fundnos.query('mgmt_cd=="AOF"')
DHM=fundnos.query('mgmt_cd=="DHM"')
WHR=fundnos.query('mgmt_cd=="WHR"')
CHP=fundnos.query('mgmt_cd=="CHP"')
PCP=fundnos.query('mgmt_cd=="PCP"')
WRH=fundnos.query('mgmt_cd=="WRH"')
UCM=fundnos.query('mgmt_cd=="UCM"')
ATC=fundnos.query('mgmt_cd=="ATC"')
AFD=fundnos.query('mgmt_cd=="AFD"')
PFC=fundnos.query('mgmt_cd=="PFC"')
FRT=fundnos.query('mgmt_cd=="FRT"')
AFR=fundnos.query('mgmt_cd=="AFR"')
RCL=fundnos.query('mgmt_cd=="RCL"')
MMF=fundnos.query('mgmt_cd=="MMF"')
HPC=fundnos.query('mgmt_cd=="HPC"')
MID=fundnos.query('mgmt_cd=="MID"')
CHS=fundnos.query('mgmt_cd=="CHS"')
GUI=fundnos.query('mgmt_cd=="GUI"')
DES=fundnos.query('mgmt_cd=="DES"')
MFF=fundnos.query('mgmt_cd=="MFF"')
HOC=fundnos.query('mgmt_cd=="HOC"')
AVA=fundnos.query('mgmt_cd=="AVA"')
MGA=fundnos.query('mgmt_cd=="MGA"')
FAS=fundnos.query('mgmt_cd=="FAS"')
CAD=fundnos.query('mgmt_cd=="CAD"')
NAM=fundnos.query('mgmt_cd=="NAM"')
LIB=fundnos.query('mgmt_cd=="LIB"')
EDL=fundnos.query('mgmt_cd=="EDL"')
BOY=fundnos.query('mgmt_cd=="BOY"')
SCD=fundnos.query('mgmt_cd=="SCD"')
ALG=fundnos.query('mgmt_cd=="ALG"')
VDR=fundnos.query('mgmt_cd=="VDR"')
NCC=fundnos.query('mgmt_cd=="NCC"')
ALE=fundnos.query('mgmt_cd=="ALE"')
PNC=fundnos.query('mgmt_cd=="PNC"')
ALL=fundnos.query('mgmt_cd=="ALL"')
AAA=fundnos.query('mgmt_cd=="AAA"')
PIM=fundnos.query('mgmt_cd=="PIM"')
ALZ=fundnos.query('mgmt_cd=="ALZ"')
MGR=fundnos.query('mgmt_cd=="MGR"')
NAP=fundnos.query('mgmt_cd=="NAP"')
RCM=fundnos.query('mgmt_cd=="RCM"')
AAI=fundnos.query('mgmt_cd=="AAI"')
TIP=fundnos.query('mgmt_cd=="TIP"')
CNC=fundnos.query('mgmt_cd=="CNC"')
ALP=fundnos.query('mgmt_cd=="ALP"')
SAT=fundnos.query('mgmt_cd=="SAT"')
ACM=fundnos.query('mgmt_cd=="ACM"')
AMR=fundnos.query('mgmt_cd=="AMR"')
VNK=fundnos.query('mgmt_cd=="VNK"')
ACI=fundnos.query('mgmt_cd=="ACI"')
MSA=fundnos.query('mgmt_cd=="MSA"')
NWM=fundnos.query('mgmt_cd=="NWM"')
JUN=fundnos.query('mgmt_cd=="JUN"')
IVM=fundnos.query('mgmt_cd=="IVM"')
AHM=fundnos.query('mgmt_cd=="AHM"')
INT=fundnos.query('mgmt_cd=="INT"')
AIF=fundnos.query('mgmt_cd=="AIF"')
AMM=fundnos.query('mgmt_cd=="AMM"')
BQT=fundnos.query('mgmt_cd=="BQT"')
APF=fundnos.query('mgmt_cd=="APF"')
SKA=fundnos.query('mgmt_cd=="SKA"')
SKI=fundnos.query('mgmt_cd=="SKI"')
SPM=fundnos.query('mgmt_cd=="SPM"')
AME=fundnos.query('mgmt_cd=="AME"')
AMI=fundnos.query('mgmt_cd=="AMI"')
CDA=fundnos.query('mgmt_cd=="CDA"')
JKA=fundnos.query('mgmt_cd=="JKA"')
COL=fundnos.query('mgmt_cd=="COL"')
CLP=fundnos.query('mgmt_cd=="CLP"')
MCP=fundnos.query('mgmt_cd=="MCP"')
CMW=fundnos.query('mgmt_cd=="CMW"')
JUM=fundnos.query('mgmt_cd=="JUM"')
STD=fundnos.query('mgmt_cd=="STD"')
TNI=fundnos.query('mgmt_cd=="TNI"')
IXI=fundnos.query('mgmt_cd=="IXI"')
ASB=fundnos.query('mgmt_cd=="ASB"')
VCP=fundnos.query('mgmt_cd=="VCP"')
ASR=fundnos.query('mgmt_cd=="ASR"')
EQA=fundnos.query('mgmt_cd=="EQA"')
ANA=fundnos.query('mgmt_cd=="ANA"')
AON=fundnos.query('mgmt_cd=="AON"')
AQM=fundnos.query('mgmt_cd=="AQM"')
APT=fundnos.query('mgmt_cd=="APT"')
WIC=fundnos.query('mgmt_cd=="WIC"')
CTZ=fundnos.query('mgmt_cd=="CTZ"')
OVB=fundnos.query('mgmt_cd=="OVB"')
ARI=fundnos.query('mgmt_cd=="ARI"')
PMU=fundnos.query('mgmt_cd=="PMU"')
PLI=fundnos.query('mgmt_cd=="PLI"')
AIB=fundnos.query('mgmt_cd=="AIB"')
AFB=fundnos.query('mgmt_cd=="AFB"')
PRT=fundnos.query('mgmt_cd=="PRT"')
ART=fundnos.query('mgmt_cd=="ART"')
SHY=fundnos.query('mgmt_cd=="SHY"')
MER=fundnos.query('mgmt_cd=="MER"')
MEL=fundnos.query('mgmt_cd=="MEL"')
AIS=fundnos.query('mgmt_cd=="AIS"')
ATA=fundnos.query('mgmt_cd=="ATA"')
IBJ=fundnos.query('mgmt_cd=="IBJ"')
ATR=fundnos.query('mgmt_cd=="ATR"')
SRI=fundnos.query('mgmt_cd=="SRI"')
ATL=fundnos.query('mgmt_cd=="ATL"')
EVK=fundnos.query('mgmt_cd=="EVK"')
WFB=fundnos.query('mgmt_cd=="WFB"')
CMB=fundnos.query('mgmt_cd=="CMB"')
AVM=fundnos.query('mgmt_cd=="AVM"')
PMF=fundnos.query('mgmt_cd=="PMF"')
BBK=fundnos.query('mgmt_cd=="BBK"')
BHR=fundnos.query('mgmt_cd=="BHR"')
AZZ=fundnos.query('mgmt_cd=="AZZ"')
BBT=fundnos.query('mgmt_cd=="BBT"')
BBH=fundnos.query('mgmt_cd=="BBH"')
BNY=fundnos.query('mgmt_cd=="BNY"')
BNM=fundnos.query('mgmt_cd=="BNM"')
GWK=fundnos.query('mgmt_cd=="GWK"')
BTC=fundnos.query('mgmt_cd=="BTC"')
BAD=fundnos.query('mgmt_cd=="BAD"')
BAR=fundnos.query('mgmt_cd=="BAR"')
BAI=fundnos.query('mgmt_cd=="BAI"')
LBR=fundnos.query('mgmt_cd=="LBR"')
STG=fundnos.query('mgmt_cd=="STG"')
FAI=fundnos.query('mgmt_cd=="FAI"')
BZW=fundnos.query('mgmt_cd=="BZW"')
BAM=fundnos.query('mgmt_cd=="BAM"')
BAN=fundnos.query('mgmt_cd=="BAN"')
RSN=fundnos.query('mgmt_cd=="RSN"')
BTA=fundnos.query('mgmt_cd=="BTA"')
SBI=fundnos.query('mgmt_cd=="SBI"')
LGW=fundnos.query('mgmt_cd=="LGW"')
BRT=fundnos.query('mgmt_cd=="BRT"')
NOM=fundnos.query('mgmt_cd=="NOM"')
BRS=fundnos.query('mgmt_cd=="BRS"')
NTC=fundnos.query('mgmt_cd=="NTC"')
BER=fundnos.query('mgmt_cd=="BER"')
BRK=fundnos.query('mgmt_cd=="BRK"')
BRN=fundnos.query('mgmt_cd=="BRN"')
KLL=fundnos.query('mgmt_cd=="KLL"')
BHI=fundnos.query('mgmt_cd=="BHI"')
BIR=fundnos.query('mgmt_cd=="BIR"')
FHB=fundnos.query('mgmt_cd=="FHB"')
BJU=fundnos.query('mgmt_cd=="BJU"')
GAB=fundnos.query('mgmt_cd=="GAB"')
BLK=fundnos.query('mgmt_cd=="BLK"')
FHC=fundnos.query('mgmt_cd=="FHC"')
BLI=fundnos.query('mgmt_cd=="BLI"')
HNW=fundnos.query('mgmt_cd=="HNW"')
BLW=fundnos.query('mgmt_cd=="BLW"')
PWR=fundnos.query('mgmt_cd=="PWR"')
BWI=fundnos.query('mgmt_cd=="BWI"')
CHK=fundnos.query('mgmt_cd=="CHK"')
CAM=fundnos.query('mgmt_cd=="CAM"')
FLT=fundnos.query('mgmt_cd=="FLT"')
CLB=fundnos.query('mgmt_cd=="CLB"')
FBB=fundnos.query('mgmt_cd=="FBB"')
BYR=fundnos.query('mgmt_cd=="BYR"')
BYL=fundnos.query('mgmt_cd=="BYL"')
BGG=fundnos.query('mgmt_cd=="BGG"')
BIP=fundnos.query('mgmt_cd=="BIP"')
FIE=fundnos.query('mgmt_cd=="FIE"')
JMC=fundnos.query('mgmt_cd=="JMC"')
PNB=fundnos.query('mgmt_cd=="PNB"')
JAC=fundnos.query('mgmt_cd=="JAC"')
PCM=fundnos.query('mgmt_cd=="PCM"')
BMR=fundnos.query('mgmt_cd=="BMR"')
BIC=fundnos.query('mgmt_cd=="BIC"')
BRG=fundnos.query('mgmt_cd=="BRG"')
UBS=fundnos.query('mgmt_cd=="UBS"')
BIA=fundnos.query('mgmt_cd=="BIA"')
BAV=fundnos.query('mgmt_cd=="BAV"')
BAF=fundnos.query('mgmt_cd=="BAF"')
BRU=fundnos.query('mgmt_cd=="BRU"')
BSR=fundnos.query('mgmt_cd=="BSR"')
BRY=fundnos.query('mgmt_cd=="BRY"')
BUF=fundnos.query('mgmt_cd=="BUF"')
CMM=fundnos.query('mgmt_cd=="CMM"')
BUL=fundnos.query('mgmt_cd=="BUL"')
BUR=fundnos.query('mgmt_cd=="BUR"')
JNY=fundnos.query('mgmt_cd=="JNY"')
CCB=fundnos.query('mgmt_cd=="CCB"')
NVE=fundnos.query('mgmt_cd=="NVE"')
JVI=fundnos.query('mgmt_cd=="JVI"')
LMS=fundnos.query('mgmt_cd=="LMS"')
OMN=fundnos.query('mgmt_cd=="OMN"')
CGM=fundnos.query('mgmt_cd=="CGM"')
VDB=fundnos.query('mgmt_cd=="VDB"')
CNB=fundnos.query('mgmt_cd=="CNB"')
ROC=fundnos.query('mgmt_cd=="ROC"')
CMA=fundnos.query('mgmt_cd=="CMA"')
AHA=fundnos.query('mgmt_cd=="AHA"')
CVS=fundnos.query('mgmt_cd=="CVS"')
RCB=fundnos.query('mgmt_cd=="RCB"')
CRM=fundnos.query('mgmt_cd=="CRM"')
CDR=fundnos.query('mgmt_cd=="CDR"')
PFM=fundnos.query('mgmt_cd=="PFM"')
CLM=fundnos.query('mgmt_cd=="CLM"')
CNO=fundnos.query('mgmt_cd=="CNO"')
RNT=fundnos.query('mgmt_cd=="RNT"')
RTA=fundnos.query('mgmt_cd=="RTA"')
CCM=fundnos.query('mgmt_cd=="CCM"')
CAF=fundnos.query('mgmt_cd=="CAF"')
COR=fundnos.query('mgmt_cd=="COR"')
CEA=fundnos.query('mgmt_cd=="CEA"')
PWA=fundnos.query('mgmt_cd=="PWA"')
CAL=fundnos.query('mgmt_cd=="CAL"')
STC=fundnos.query('mgmt_cd=="STC"')
CPM=fundnos.query('mgmt_cd=="CPM"')
HNB=fundnos.query('mgmt_cd=="HNB"')
MAC=fundnos.query('mgmt_cd=="MAC"')
CAP=fundnos.query('mgmt_cd=="CAP"')
SCU=fundnos.query('mgmt_cd=="SCU"')
PRU=fundnos.query('mgmt_cd=="PRU"')
JDR=fundnos.query('mgmt_cd=="JDR"')
PCE=fundnos.query('mgmt_cd=="PCE"')
FED=fundnos.query('mgmt_cd=="FED"')
CKF=fundnos.query('mgmt_cd=="CKF"')
CAU=fundnos.query('mgmt_cd=="CAU"')
CCO=fundnos.query('mgmt_cd=="CCO"')
CNT=fundnos.query('mgmt_cd=="CNT"')
INV=fundnos.query('mgmt_cd=="INV"')
EPL=fundnos.query('mgmt_cd=="EPL"')
UTN=fundnos.query('mgmt_cd=="UTN"')
CHN=fundnos.query('mgmt_cd=="CHN"')
CHL=fundnos.query('mgmt_cd=="CHL"')
CHO=fundnos.query('mgmt_cd=="CHO"')
CCL=fundnos.query('mgmt_cd=="CCL"')
CIG=fundnos.query('mgmt_cd=="CIG"')
CIT=fundnos.query('mgmt_cd=="CIT"')
CZA=fundnos.query('mgmt_cd=="CZA"')
MYR=fundnos.query('mgmt_cd=="MYR"')
CLY=fundnos.query('mgmt_cd=="CLY"')
ZIM=fundnos.query('mgmt_cd=="ZIM"')
PFR=fundnos.query('mgmt_cd=="PFR"')
CPR=fundnos.query('mgmt_cd=="CPR"')
CSM=fundnos.query('mgmt_cd=="CSM"')
FID=fundnos.query('mgmt_cd=="FID"')
CLN=fundnos.query('mgmt_cd=="CLN"')
FRD=fundnos.query('mgmt_cd=="FRD"')
WNG=fundnos.query('mgmt_cd=="WNG"')
SRF=fundnos.query('mgmt_cd=="SRF"')
CRB=fundnos.query('mgmt_cd=="CRB"')
SMT=fundnos.query('mgmt_cd=="SMT"')
BOA=fundnos.query('mgmt_cd=="BOA"')
LBY=fundnos.query('mgmt_cd=="LBY"')
COM=fundnos.query('mgmt_cd=="COM"')
FCA=fundnos.query('mgmt_cd=="FCA"')
CRF=fundnos.query('mgmt_cd=="CRF"')
CPI=fundnos.query('mgmt_cd=="CPI"')
CFC=fundnos.query('mgmt_cd=="CFC"')
CTA=fundnos.query('mgmt_cd=="CTA"')
CON=fundnos.query('mgmt_cd=="CON"')
TOU=fundnos.query('mgmt_cd=="TOU"')
TTN=fundnos.query('mgmt_cd=="TTN"')
TUR=fundnos.query('mgmt_cd=="TUR"')
CLV=fundnos.query('mgmt_cd=="CLV"')
HIL=fundnos.query('mgmt_cd=="HIL"')
CGC=fundnos.query('mgmt_cd=="CGC"')
CPY=fundnos.query('mgmt_cd=="CPY"')
WYC=fundnos.query('mgmt_cd=="WYC"')
IAA=fundnos.query('mgmt_cd=="IAA"')
AFM=fundnos.query('mgmt_cd=="AFM"')
UTB=fundnos.query('mgmt_cd=="UTB"')
HUM=fundnos.query('mgmt_cd=="HUM"')
FSB=fundnos.query('mgmt_cd=="FSB"')
WAI=fundnos.query('mgmt_cd=="WAI"')
SCI=fundnos.query('mgmt_cd=="SCI"')
WMT=fundnos.query('mgmt_cd=="WMT"')
IMM=fundnos.query('mgmt_cd=="IMM"')
SHL=fundnos.query('mgmt_cd=="SHL"')
BRE=fundnos.query('mgmt_cd=="BRE"')
COW=fundnos.query('mgmt_cd=="COW"')
DLJ=fundnos.query('mgmt_cd=="DLJ"')
ABR=fundnos.query('mgmt_cd=="ABR"')
CRO=fundnos.query('mgmt_cd=="CRO"')
SWC=fundnos.query('mgmt_cd=="SWC"')
CUL=fundnos.query('mgmt_cd=="CUL"')
PAD=fundnos.query('mgmt_cd=="PAD"')
RYD=fundnos.query('mgmt_cd=="RYD"')
SMC=fundnos.query('mgmt_cd=="SMC"')
CUT=fundnos.query('mgmt_cd=="CUT"')
DFA=fundnos.query('mgmt_cd=="DFA"')
DEL=fundnos.query('mgmt_cd=="DEL"')
KMP=fundnos.query('mgmt_cd=="KMP"')
RRE=fundnos.query('mgmt_cd=="RRE"')
BRA=fundnos.query('mgmt_cd=="BRA"')
DEU=fundnos.query('mgmt_cd=="DEU"')
DSA=fundnos.query('mgmt_cd=="DSA"')
DEN=fundnos.query('mgmt_cd=="DEN"')
TAM=fundnos.query('mgmt_cd=="TAM"')
DCT=fundnos.query('mgmt_cd=="DCT"')
KLD=fundnos.query('mgmt_cd=="KLD"')
CHR=fundnos.query('mgmt_cd=="CHR"')
DHC=fundnos.query('mgmt_cd=="DHC"')
HAG=fundnos.query('mgmt_cd=="HAG"')
SSB=fundnos.query('mgmt_cd=="SSB"')
RAM=fundnos.query('mgmt_cd=="RAM"')
AVP=fundnos.query('mgmt_cd=="AVP"')
DVF=fundnos.query('mgmt_cd=="DVF"')
EPA=fundnos.query('mgmt_cd=="EPA"')
DGA=fundnos.query('mgmt_cd=="DGA"')
GSC=fundnos.query('mgmt_cd=="GSC"')
DNC=fundnos.query('mgmt_cd=="DNC"')
DOM=fundnos.query('mgmt_cd=="DOM"')
ISG=fundnos.query('mgmt_cd=="ISG"')
NYE=fundnos.query('mgmt_cd=="NYE"')
WII=fundnos.query('mgmt_cd=="WII"')
FND=fundnos.query('mgmt_cd=="FND"')
DRI=fundnos.query('mgmt_cd=="DRI"')
TUP=fundnos.query('mgmt_cd=="TUP"')
TPF=fundnos.query('mgmt_cd=="TPF"')
DUP=fundnos.query('mgmt_cd=="DUP"')
EVL=fundnos.query('mgmt_cd=="EVL"')
EII=fundnos.query('mgmt_cd=="EII"')
ETR=fundnos.query('mgmt_cd=="ETR"')
KBN=fundnos.query('mgmt_cd=="KBN"')
BFC=fundnos.query('mgmt_cd=="BFC"')
EAT=fundnos.query('mgmt_cd=="EAT"')
TNC=fundnos.query('mgmt_cd=="TNC"')
ECL=fundnos.query('mgmt_cd=="ECL"')
MNS=fundnos.query('mgmt_cd=="MNS"')
NYL=fundnos.query('mgmt_cd=="NYL"')
EKN=fundnos.query('mgmt_cd=="EKN"')
MOH=fundnos.query('mgmt_cd=="MOH"')
GEE=fundnos.query('mgmt_cd=="GEE"')
MCC=fundnos.query('mgmt_cd=="MCC"')
EMR=fundnos.query('mgmt_cd=="EMR"')
GLI=fundnos.query('mgmt_cd=="GLI"')
FAU=fundnos.query('mgmt_cd=="FAU"')
SWM=fundnos.query('mgmt_cd=="SWM"')
EQU=fundnos.query('mgmt_cd=="EQU"')
SNW=fundnos.query('mgmt_cd=="SNW"')
EFM=fundnos.query('mgmt_cd=="EFM"')
OFF=fundnos.query('mgmt_cd=="OFF"')
WCH=fundnos.query('mgmt_cd=="WCH"')
UND=fundnos.query('mgmt_cd=="UND"')
GMO=fundnos.query('mgmt_cd=="GMO"')
SOA=fundnos.query('mgmt_cd=="SOA"')
UST=fundnos.query('mgmt_cd=="UST"')
FIM=fundnos.query('mgmt_cd=="FIM"')
CMP=fundnos.query('mgmt_cd=="CMP"')
FTW=fundnos.query('mgmt_cd=="FTW"')
MMA=fundnos.query('mgmt_cd=="MMA"')
AGA=fundnos.query('mgmt_cd=="AGA"')
FDU=fundnos.query('mgmt_cd=="FDU"')
RCA=fundnos.query('mgmt_cd=="RCA"')
PVT=fundnos.query('mgmt_cd=="PVT"')
FPA=fundnos.query('mgmt_cd=="FPA"')
FTI=fundnos.query('mgmt_cd=="FTI"')
FRA=fundnos.query('mgmt_cd=="FRA"')
BRO=fundnos.query('mgmt_cd=="BRO"')
FRH=fundnos.query('mgmt_cd=="FRH"')
SAC=fundnos.query('mgmt_cd=="SAC"')
RCO=fundnos.query('mgmt_cd=="RCO"')
EDG=fundnos.query('mgmt_cd=="EDG"')
HBS=fundnos.query('mgmt_cd=="HBS"')
MDT=fundnos.query('mgmt_cd=="MDT"')
FEN=fundnos.query('mgmt_cd=="FEN"')
SEI=fundnos.query('mgmt_cd=="SEI"')
FTM=fundnos.query('mgmt_cd=="FTM"')
MAU=fundnos.query('mgmt_cd=="MAU"')
FTB=fundnos.query('mgmt_cd=="FTB"')
OKB=fundnos.query('mgmt_cd=="OKB"')
TEM=fundnos.query('mgmt_cd=="TEM"')
UBP=fundnos.query('mgmt_cd=="UBP"')
NUV=fundnos.query('mgmt_cd=="NUV"')
USB=fundnos.query('mgmt_cd=="USB"')
FIR=fundnos.query('mgmt_cd=="FIR"')
FAC=fundnos.query('mgmt_cd=="FAC"')
ARB=fundnos.query('mgmt_cd=="ARB"')
FES=fundnos.query('mgmt_cd=="FES"')
FEG=fundnos.query('mgmt_cd=="FEG"')
FNO=fundnos.query('mgmt_cd=="FNO"')
TRB=fundnos.query('mgmt_cd=="TRB"')
FFS=fundnos.query('mgmt_cd=="FFS"')
FTN=fundnos.query('mgmt_cd=="FTN"')
FPM=fundnos.query('mgmt_cd=="FPM"')
FTA=fundnos.query('mgmt_cd=="FTA"')
SIV=fundnos.query('mgmt_cd=="SIV"')
FNQ=fundnos.query('mgmt_cd=="FNQ"')
FLM=fundnos.query('mgmt_cd=="FLM"')
JPM=fundnos.query('mgmt_cd=="JPM"')
MED=fundnos.query('mgmt_cd=="MED"')
FAM=fundnos.query('mgmt_cd=="FAM"')
FOS=fundnos.query('mgmt_cd=="FOS"')
FPC=fundnos.query('mgmt_cd=="FPC"')
FOR=fundnos.query('mgmt_cd=="FOR"')
HMF=fundnos.query('mgmt_cd=="HMF"')
DVR=fundnos.query('mgmt_cd=="DVR"')
MRK=fundnos.query('mgmt_cd=="MRK"')
ABS=fundnos.query('mgmt_cd=="ABS"')
ABI=fundnos.query('mgmt_cd=="ABI"')
WSL=fundnos.query('mgmt_cd=="WSL"')
NEV=fundnos.query('mgmt_cd=="NEV"')
SGB=fundnos.query('mgmt_cd=="SGB"')
GCL=fundnos.query('mgmt_cd=="GCL"')
AUX=fundnos.query('mgmt_cd=="AUX"')
WIN=fundnos.query('mgmt_cd=="WIN"')
BCM=fundnos.query('mgmt_cd=="BCM"')
AHH=fundnos.query('mgmt_cd=="AHH"')
AHL=fundnos.query('mgmt_cd=="AHL"')
SHK=fundnos.query('mgmt_cd=="SHK"')
DFD=fundnos.query('mgmt_cd=="DFD"')
TRL=fundnos.query('mgmt_cd=="TRL"')
MQA=fundnos.query('mgmt_cd=="MQA"')
PLS=fundnos.query('mgmt_cd=="PLS"')
AUS=fundnos.query('mgmt_cd=="AUS"')
BMO=fundnos.query('mgmt_cd=="BMO"')
PAY=fundnos.query('mgmt_cd=="PAY"')
PCT=fundnos.query('mgmt_cd=="PCT"')
FCP=fundnos.query('mgmt_cd=="FCP"')
FRE=fundnos.query('mgmt_cd=="FRE"')
FIA=fundnos.query('mgmt_cd=="FIA"')
FIV=fundnos.query('mgmt_cd=="FIV"')
SIA=fundnos.query('mgmt_cd=="SIA"')
IRB=fundnos.query('mgmt_cd=="IRB"')
FIC=fundnos.query('mgmt_cd=="FIC"')
DAL=fundnos.query('mgmt_cd=="DAL"')
HFM=fundnos.query('mgmt_cd=="HFM"')
GKM=fundnos.query('mgmt_cd=="GKM"')
FWI=fundnos.query('mgmt_cd=="FWI"')
IVH=fundnos.query('mgmt_cd=="IVH"')
GAM=fundnos.query('mgmt_cd=="GAM"')
MTH=fundnos.query('mgmt_cd=="MTH"')
GLM=fundnos.query('mgmt_cd=="GLM"')
GMN=fundnos.query('mgmt_cd=="GMN"')
GIA=fundnos.query('mgmt_cd=="GIA"')
GEO=fundnos.query('mgmt_cd=="GEO"')
WGI=fundnos.query('mgmt_cd=="WGI"')
GIN=fundnos.query('mgmt_cd=="GIN"')
GIO=fundnos.query('mgmt_cd=="GIO"')
GLT=fundnos.query('mgmt_cd=="GLT"')
GLD=fundnos.query('mgmt_cd=="GLD"')
COC=fundnos.query('mgmt_cd=="COC"')
TGT=fundnos.query('mgmt_cd=="TGT"')
GRN=fundnos.query('mgmt_cd=="GRN"')
GCC=fundnos.query('mgmt_cd=="GCC"')
KEM=fundnos.query('mgmt_cd=="KEM"')
GAA=fundnos.query('mgmt_cd=="GAA"')
HSB=fundnos.query('mgmt_cd=="HSB"')
REP=fundnos.query('mgmt_cd=="REP"')
HTS=fundnos.query('mgmt_cd=="HTS"')
RES=fundnos.query('mgmt_cd=="RES"')
SEG=fundnos.query('mgmt_cd=="SEG"')
ROA=fundnos.query('mgmt_cd=="ROA"')
TWC=fundnos.query('mgmt_cd=="TWC"')
FRV=fundnos.query('mgmt_cd=="FRV"')
HNQ=fundnos.query('mgmt_cd=="HNQ"')
LIX=fundnos.query('mgmt_cd=="LIX"')
PZE=fundnos.query('mgmt_cd=="PZE"')
YWM=fundnos.query('mgmt_cd=="YWM"')
HNC=fundnos.query('mgmt_cd=="HNC"')
HHF=fundnos.query('mgmt_cd=="HHF"')
IIN=fundnos.query('mgmt_cd=="IIN"')
HAN=fundnos.query('mgmt_cd=="HAN"')
HCA=fundnos.query('mgmt_cd=="HCA"')
HLM=fundnos.query('mgmt_cd=="HLM"')
HRR=fundnos.query('mgmt_cd=="HRR"')
OKM=fundnos.query('mgmt_cd=="OKM"')
PHX=fundnos.query('mgmt_cd=="PHX"')
HRT=fundnos.query('mgmt_cd=="HRT"')
HTD=fundnos.query('mgmt_cd=="HTD"')
HAI=fundnos.query('mgmt_cd=="HAI"')
HND=fundnos.query('mgmt_cd=="HND"')
OSH=fundnos.query('mgmt_cd=="OSH"')
LAN=fundnos.query('mgmt_cd=="LAN"')
HNL=fundnos.query('mgmt_cd=="HNL"')
HEF=fundnos.query('mgmt_cd=="HEF"')
HER=fundnos.query('mgmt_cd=="HER"')
EAG=fundnos.query('mgmt_cd=="EAG"')
HCM=fundnos.query('mgmt_cd=="HCM"')
UBC=fundnos.query('mgmt_cd=="UBC"')
HMK=fundnos.query('mgmt_cd=="HMK"')
HLC=fundnos.query('mgmt_cd=="HLC"')
JJB=fundnos.query('mgmt_cd=="JJB"')
REM=fundnos.query('mgmt_cd=="REM"')
HOL=fundnos.query('mgmt_cd=="HOL"')
REA=fundnos.query('mgmt_cd=="REA"')
HWC=fundnos.query('mgmt_cd=="HWC"')
HOU=fundnos.query('mgmt_cd=="HOU"')
HOW=fundnos.query('mgmt_cd=="HOW"')
HUD=fundnos.query('mgmt_cd=="HUD"')
HUN=fundnos.query('mgmt_cd=="HUN"')
HNT=fundnos.query('mgmt_cd=="HNT"')
HUS=fundnos.query('mgmt_cd=="HUS"')
ICC=fundnos.query('mgmt_cd=="ICC"')
MRD=fundnos.query('mgmt_cd=="MRD"')
ICN=fundnos.query('mgmt_cd=="ICN"')
IGA=fundnos.query('mgmt_cd=="IGA"')
VNT=fundnos.query('mgmt_cd=="VNT"')
IMG=fundnos.query('mgmt_cd=="IMG"')
ING=fundnos.query('mgmt_cd=="ING"')
LEK=fundnos.query('mgmt_cd=="LEK"')
AET=fundnos.query('mgmt_cd=="AET"')
CRA=fundnos.query('mgmt_cd=="CRA"')
IPA=fundnos.query('mgmt_cd=="IPA"')
ISI=fundnos.query('mgmt_cd=="ISI"')
IDX=fundnos.query('mgmt_cd=="IDX"')
CIP=fundnos.query('mgmt_cd=="CIP"')
PRI=fundnos.query('mgmt_cd=="PRI"')
NDM=fundnos.query('mgmt_cd=="NDM"')
VIK=fundnos.query('mgmt_cd=="VIK"')
CND=fundnos.query('mgmt_cd=="CND"')
KIN=fundnos.query('mgmt_cd=="KIN"')
ICP=fundnos.query('mgmt_cd=="ICP"')
WCA=fundnos.query('mgmt_cd=="WCA"')
IRN=fundnos.query('mgmt_cd=="IRN"')
IVY=fundnos.query('mgmt_cd=="IVY"')
WNR=fundnos.query('mgmt_cd=="WNR"')
AEW=fundnos.query('mgmt_cd=="AEW"')
JCK=fundnos.query('mgmt_cd=="JCK"')
JIR=fundnos.query('mgmt_cd=="JIR"')
JAN=fundnos.query('mgmt_cd=="JAN"')
FMT=fundnos.query('mgmt_cd=="FMT"')
INL=fundnos.query('mgmt_cd=="INL"')
JEN=fundnos.query('mgmt_cd=="JEN"')
JAM=fundnos.query('mgmt_cd=="JAM"')
JIC=fundnos.query('mgmt_cd=="JIC"')
EDJ=fundnos.query('mgmt_cd=="EDJ"')
BCO=fundnos.query('mgmt_cd=="BCO"')
ONG=fundnos.query('mgmt_cd=="ONG"')
SCG=fundnos.query('mgmt_cd=="SCG"')
BJB=fundnos.query('mgmt_cd=="BJB"')
KPM=fundnos.query('mgmt_cd=="KPM"')
KIA=fundnos.query('mgmt_cd=="KIA"')
KLY=fundnos.query('mgmt_cd=="KLY"')
KEL=fundnos.query('mgmt_cd=="KEL"')
IPS=fundnos.query('mgmt_cd=="IPS"')
KNS=fundnos.query('mgmt_cd=="KNS"')
KNW=fundnos.query('mgmt_cd=="KNW"')
CCI=fundnos.query('mgmt_cd=="CCI"')
KIR=fundnos.query('mgmt_cd=="KIR"')
KIT=fundnos.query('mgmt_cd=="KIT"')
KOP=fundnos.query('mgmt_cd=="KOP"')
LKC=fundnos.query('mgmt_cd=="LKC"')
AQU=fundnos.query('mgmt_cd=="AQU"')
LEG=fundnos.query('mgmt_cd=="LEG"')
LAC=fundnos.query('mgmt_cd=="LAC"')
LAS=fundnos.query('mgmt_cd=="LAS"')
BOB=fundnos.query('mgmt_cd=="BOB"')
LKS=fundnos.query('mgmt_cd=="LKS"')
CSW=fundnos.query('mgmt_cd=="CSW"')
VAN=fundnos.query('mgmt_cd=="VAN"')
LAZ=fundnos.query('mgmt_cd=="LAZ"')
UPL=fundnos.query('mgmt_cd=="UPL"')
LDR=fundnos.query('mgmt_cd=="LDR"')
LEB=fundnos.query('mgmt_cd=="LEB"')
INS=fundnos.query('mgmt_cd=="INS"')
FFC=fundnos.query('mgmt_cd=="FFC"')
NEU=fundnos.query('mgmt_cd=="NEU"')
LEP=fundnos.query('mgmt_cd=="LEP"')
LEU=fundnos.query('mgmt_cd=="LEU"')
MNR=fundnos.query('mgmt_cd=="MNR"')
LBH=fundnos.query('mgmt_cd=="LBH"')
RYB=fundnos.query('mgmt_cd=="RYB"')
LIP=fundnos.query('mgmt_cd=="LIP"')
LLP=fundnos.query('mgmt_cd=="LLP"')
LRD=fundnos.query('mgmt_cd=="LRD"')
WHI=fundnos.query('mgmt_cd=="WHI"')
LOT=fundnos.query('mgmt_cd=="LOT"')
HLL=fundnos.query('mgmt_cd=="HLL"')
LUT=fundnos.query('mgmt_cd=="LUT"')
MDC=fundnos.query('mgmt_cd=="MDC"')
MFS=fundnos.query('mgmt_cd=="MFS"')
PEN=fundnos.query('mgmt_cd=="PEN"')
PNS=fundnos.query('mgmt_cd=="PNS"')
CQF=fundnos.query('mgmt_cd=="CQF"')
MAS=fundnos.query('mgmt_cd=="MAS"')
MHE=fundnos.query('mgmt_cd=="MHE"')
MMC=fundnos.query('mgmt_cd=="MMC"')
MPA=fundnos.query('mgmt_cd=="MPA"')
MTB=fundnos.query('mgmt_cd=="MTB"')
MNT=fundnos.query('mgmt_cd=="MNT"')
GVR=fundnos.query('mgmt_cd=="GVR"')
WIL=fundnos.query('mgmt_cd=="WIL"')
BFA=fundnos.query('mgmt_cd=="BFA"')
MAD=fundnos.query('mgmt_cd=="MAD"')
MPI=fundnos.query('mgmt_cd=="MPI"')
TMS=fundnos.query('mgmt_cd=="TMS"')
SBA=fundnos.query('mgmt_cd=="SBA"')
MAN=fundnos.query('mgmt_cd=="MAN"')
MOS=fundnos.query('mgmt_cd=="MOS"')
DNH=fundnos.query('mgmt_cd=="DNH"')
IGN=fundnos.query('mgmt_cd=="IGN"')
MKF=fundnos.query('mgmt_cd=="MKF"')
MKM=fundnos.query('mgmt_cd=="MKM"')
MNI=fundnos.query('mgmt_cd=="MNI"')
MRS=fundnos.query('mgmt_cd=="MRS"')
MML=fundnos.query('mgmt_cd=="MML"')
LTG=fundnos.query('mgmt_cd=="LTG"')
HMG=fundnos.query('mgmt_cd=="HMG"')
MTX=fundnos.query('mgmt_cd=="MTX"')
MAT=fundnos.query('mgmt_cd=="MAT"')
MAW=fundnos.query('mgmt_cd=="MAW"')
MIN=fundnos.query('mgmt_cd=="MIN"')
MCM=fundnos.query('mgmt_cd=="MCM"')
SAW=fundnos.query('mgmt_cd=="SAW"')
MIF=fundnos.query('mgmt_cd=="MIF"')
CUN=fundnos.query('mgmt_cd=="CUN"')
CIM=fundnos.query('mgmt_cd=="CIM"')
MEM=fundnos.query('mgmt_cd=="MEM"')
PRK=fundnos.query('mgmt_cd=="PRK"')
MSD=fundnos.query('mgmt_cd=="MSD"')
WCM=fundnos.query('mgmt_cd=="WCM"')
AST=fundnos.query('mgmt_cd=="AST"')
ARR=fundnos.query('mgmt_cd=="ARR"')
MRT=fundnos.query('mgmt_cd=="MRT"')
IBT=fundnos.query('mgmt_cd=="IBT"')
MRM=fundnos.query('mgmt_cd=="MRM"')
MTM=fundnos.query('mgmt_cd=="MTM"')
MZP=fundnos.query('mgmt_cd=="MZP"')
MTO=fundnos.query('mgmt_cd=="MTO"')
BNB=fundnos.query('mgmt_cd=="BNB"')
PDR=fundnos.query('mgmt_cd=="PDR"')
MIL=fundnos.query('mgmt_cd=="MIL"')
TRS=fundnos.query('mgmt_cd=="TRS"')
RID=fundnos.query('mgmt_cd=="RID"')
MLM=fundnos.query('mgmt_cd=="MLM"')
MFN=fundnos.query('mgmt_cd=="MFN"')
NSV=fundnos.query('mgmt_cd=="NSV"')
MAM=fundnos.query('mgmt_cd=="MAM"')
MON=fundnos.query('mgmt_cd=="MON"')
MRG=fundnos.query('mgmt_cd=="MRG"')
REG=fundnos.query('mgmt_cd=="REG"')
MUN=fundnos.query('mgmt_cd=="MUN"')
KYC=fundnos.query('mgmt_cd=="KYC"')
AQJ=fundnos.query('mgmt_cd=="AQJ"')
MDV=fundnos.query('mgmt_cd=="MDV"')
MAI=fundnos.query('mgmt_cd=="MAI"')
MUT=fundnos.query('mgmt_cd=="MUT"')
ONE=fundnos.query('mgmt_cd=="ONE"')
NBP=fundnos.query('mgmt_cd=="NBP"')
NKM=fundnos.query('mgmt_cd=="NKM"')
NAV=fundnos.query('mgmt_cd=="NAV"')
NEE=fundnos.query('mgmt_cd=="NEE"')
NCM=fundnos.query('mgmt_cd=="NCM"')
NFM=fundnos.query('mgmt_cd=="NFM"')
ACC=fundnos.query('mgmt_cd=="ACC"')
WES=fundnos.query('mgmt_cd=="WES"')
NCT=fundnos.query('mgmt_cd=="NCT"')
NPC=fundnos.query('mgmt_cd=="NPC"')
NRV=fundnos.query('mgmt_cd=="NRV"')
SSU=fundnos.query('mgmt_cd=="SSU"')
PNA=fundnos.query('mgmt_cd=="PNA"')
DUN=fundnos.query('mgmt_cd=="DUN"')
NCI=fundnos.query('mgmt_cd=="NCI"')
PMC=fundnos.query('mgmt_cd=="PMC"')
MSS=fundnos.query('mgmt_cd=="MSS"')
VLC=fundnos.query('mgmt_cd=="VLC"')
CYP=fundnos.query('mgmt_cd=="CYP"')
NOC=fundnos.query('mgmt_cd=="NOC"')
ZNC=fundnos.query('mgmt_cd=="ZNC"')
NTM=fundnos.query('mgmt_cd=="NTM"')
JNC=fundnos.query('mgmt_cd=="JNC"')
GCF=fundnos.query('mgmt_cd=="GCF"')
BIO=fundnos.query('mgmt_cd=="BIO"')
APM=fundnos.query('mgmt_cd=="APM"')
RLC=fundnos.query('mgmt_cd=="RLC"')
CPT=fundnos.query('mgmt_cd=="CPT"')
CGI=fundnos.query('mgmt_cd=="CGI"')
CIC=fundnos.query('mgmt_cd=="CIC"')
BWN=fundnos.query('mgmt_cd=="BWN"')
WBK=fundnos.query('mgmt_cd=="WBK"')
PBA=fundnos.query('mgmt_cd=="PBA"')
OPC=fundnos.query('mgmt_cd=="OPC"')
OAK=fundnos.query('mgmt_cd=="OAK"')
OVC=fundnos.query('mgmt_cd=="OVC"')
RSC=fundnos.query('mgmt_cd=="RSC"')
OAM=fundnos.query('mgmt_cd=="OAM"')
VLI=fundnos.query('mgmt_cd=="VLI"')
ISE=fundnos.query('mgmt_cd=="ISE"')
OMC=fundnos.query('mgmt_cd=="OMC"')
HTM=fundnos.query('mgmt_cd=="HTM"')
BES=fundnos.query('mgmt_cd=="BES"')
OLS=fundnos.query('mgmt_cd=="OLS"')
ETE=fundnos.query('mgmt_cd=="ETE"')
QHN=fundnos.query('mgmt_cd=="QHN"')
ORR=fundnos.query('mgmt_cd=="ORR"')
PIC=fundnos.query('mgmt_cd=="PIC"')
MMM=fundnos.query('mgmt_cd=="MMM"')
PGL=fundnos.query('mgmt_cd=="PGL"')
PAP=fundnos.query('mgmt_cd=="PAP"')
PDM=fundnos.query('mgmt_cd=="PDM"')
GIS=fundnos.query('mgmt_cd=="GIS"')
PIN=fundnos.query('mgmt_cd=="PIN"')
PZS=fundnos.query('mgmt_cd=="PZS"')
PAX=fundnos.query('mgmt_cd=="PAX"')
PLM=fundnos.query('mgmt_cd=="PLM"')
PAA=fundnos.query('mgmt_cd=="PAA"')
QUA=fundnos.query('mgmt_cd=="QUA"')
TMN=fundnos.query('mgmt_cd=="TMN"')
WMM=fundnos.query('mgmt_cd=="WMM"')
PPF=fundnos.query('mgmt_cd=="PPF"')
PRR=fundnos.query('mgmt_cd=="PRR"')
VUI=fundnos.query('mgmt_cd=="VUI"')
PHA=fundnos.query('mgmt_cd=="PHA"')
KAY=fundnos.query('mgmt_cd=="KAY"')
CLK=fundnos.query('mgmt_cd=="CLK"')
SSA=fundnos.query('mgmt_cd=="SSA"')
PNE=fundnos.query('mgmt_cd=="PNE"')
ORI=fundnos.query('mgmt_cd=="ORI"')
ORD=fundnos.query('mgmt_cd=="ORD"')
SAF=fundnos.query('mgmt_cd=="SAF"')
PIT=fundnos.query('mgmt_cd=="PIT"')
POP=fundnos.query('mgmt_cd=="POP"')
PAR=fundnos.query('mgmt_cd=="PAR"')
MTR=fundnos.query('mgmt_cd=="MTR"')
DBC=fundnos.query('mgmt_cd=="DBC"')
MFL=fundnos.query('mgmt_cd=="MFL"')
CAT=fundnos.query('mgmt_cd=="CAT"')
KCO=fundnos.query('mgmt_cd=="KCO"')
PRM=fundnos.query('mgmt_cd=="PRM"')
PRV=fundnos.query('mgmt_cd=="PRV"')
HOD=fundnos.query('mgmt_cd=="HOD"')
PKN=fundnos.query('mgmt_cd=="PKN"')
JMK=fundnos.query('mgmt_cd=="JMK"')
SIM=fundnos.query('mgmt_cd=="SIM"')
FMC=fundnos.query('mgmt_cd=="FMC"')
OST=fundnos.query('mgmt_cd=="OST"')
TYE=fundnos.query('mgmt_cd=="TYE"')
GCM=fundnos.query('mgmt_cd=="GCM"')
STV=fundnos.query('mgmt_cd=="STV"')
PGR=fundnos.query('mgmt_cd=="PGR"')
PRO=fundnos.query('mgmt_cd=="PRO"')
SHR=fundnos.query('mgmt_cd=="SHR"')
HES=fundnos.query('mgmt_cd=="HES"')
LIG=fundnos.query('mgmt_cd=="LIG"')
LEO=fundnos.query('mgmt_cd=="LEO"')
SWR=fundnos.query('mgmt_cd=="SWR"')
IRG=fundnos.query('mgmt_cd=="IRG"')
PFT=fundnos.query('mgmt_cd=="PFT"')
PAL=fundnos.query('mgmt_cd=="PAL"')
TIC=fundnos.query('mgmt_cd=="TIC"')
FIS=fundnos.query('mgmt_cd=="FIS"')
PUT=fundnos.query('mgmt_cd=="PUT"')
QAI=fundnos.query('mgmt_cd=="QAI"')
BPA=fundnos.query('mgmt_cd=="BPA"')
RBO=fundnos.query('mgmt_cd=="RBO"')
BOG=fundnos.query('mgmt_cd=="BOG"')
NUM=fundnos.query('mgmt_cd=="NUM"')
SCN=fundnos.query('mgmt_cd=="SCN"')
WPG=fundnos.query('mgmt_cd=="WPG"')
CEN=fundnos.query('mgmt_cd=="CEN"')
RNC=fundnos.query('mgmt_cd=="RNC"')
RSI=fundnos.query('mgmt_cd=="RSI"')
FUR=fundnos.query('mgmt_cd=="FUR"')
RAI=fundnos.query('mgmt_cd=="RAI"')
RPI=fundnos.query('mgmt_cd=="RPI"')
REN=fundnos.query('mgmt_cd=="REN"')
REY=fundnos.query('mgmt_cd=="REY"')
RIC=fundnos.query('mgmt_cd=="RIC"')
RIM=fundnos.query('mgmt_cd=="RIM"')
RIT=fundnos.query('mgmt_cd=="RIT"')
PRB=fundnos.query('mgmt_cd=="PRB"')
RCK=fundnos.query('mgmt_cd=="RCK"')
GIP=fundnos.query('mgmt_cd=="GIP"')
RWR=fundnos.query('mgmt_cd=="RWR"')
RSS=fundnos.query('mgmt_cd=="RSS"')
RUN=fundnos.query('mgmt_cd=="RUN"')
RFD=fundnos.query('mgmt_cd=="RFD"')
RUS=fundnos.query('mgmt_cd=="RUS"')
AAM=fundnos.query('mgmt_cd=="AAM"')
SIX=fundnos.query('mgmt_cd=="SIX"')
SIT=fundnos.query('mgmt_cd=="SIT"')
SMR=fundnos.query('mgmt_cd=="SMR"')
STI=fundnos.query('mgmt_cd=="STI"')
SBG=fundnos.query('mgmt_cd=="SBG"')
HCW=fundnos.query('mgmt_cd=="HCW"')
TOI=fundnos.query('mgmt_cd=="TOI"')
SRT=fundnos.query('mgmt_cd=="SRT"')
STU=fundnos.query('mgmt_cd=="STU"')
SCH=fundnos.query('mgmt_cd=="SCH"')
SWZ=fundnos.query('mgmt_cd=="SWZ"')
SCM=fundnos.query('mgmt_cd=="SCM"')
SET=fundnos.query('mgmt_cd=="SET"')
SLG=fundnos.query('mgmt_cd=="SLG"')
SEL=fundnos.query('mgmt_cd=="SEL"')
BRM=fundnos.query('mgmt_cd=="BRM"')
SEN=fundnos.query('mgmt_cd=="SEN"')
RCC=fundnos.query('mgmt_cd=="RCC"')
SIC=fundnos.query('mgmt_cd=="SIC"')
SFE=fundnos.query('mgmt_cd=="SFE"')
SHC=fundnos.query('mgmt_cd=="SHC"')
SKY=fundnos.query('mgmt_cd=="SKY"')
SKF=fundnos.query('mgmt_cd=="SKF"')
SSM=fundnos.query('mgmt_cd=="SSM"')
SPW=fundnos.query('mgmt_cd=="SPW"')
SPX=fundnos.query('mgmt_cd=="SPX"')
SPT=fundnos.query('mgmt_cd=="SPT"')
STR=fundnos.query('mgmt_cd=="STR"')
STA=fundnos.query('mgmt_cd=="STA"')
SFI=fundnos.query('mgmt_cd=="SFI"')
WPS=fundnos.query('mgmt_cd=="WPS"')
PWO=fundnos.query('mgmt_cd=="PWO"')
SJC=fundnos.query('mgmt_cd=="SJC"')
STQ=fundnos.query('mgmt_cd=="STQ"')
SCC=fundnos.query('mgmt_cd=="SCC"')
STT=fundnos.query('mgmt_cd=="STT"')
UBT=fundnos.query('mgmt_cd=="UBT"')
FSC=fundnos.query('mgmt_cd=="FSC"')
SIP=fundnos.query('mgmt_cd=="SIP"')
SML=fundnos.query('mgmt_cd=="SML"')
SYC=fundnos.query('mgmt_cd=="SYC"')
TCW=fundnos.query('mgmt_cd=="TCW"')
WTH=fundnos.query('mgmt_cd=="WTH"')
TFS=fundnos.query('mgmt_cd=="TFS"')
TIA=fundnos.query('mgmt_cd=="TIA"')
TTI=fundnos.query('mgmt_cd=="TTI"')
IFG=fundnos.query('mgmt_cd=="IFG"')
TAN=fundnos.query('mgmt_cd=="TAN"')
VTA=fundnos.query('mgmt_cd=="VTA"')
EQS=fundnos.query('mgmt_cd=="EQS"')
THD=fundnos.query('mgmt_cd=="THD"')
THR=fundnos.query('mgmt_cd=="THR"')
ALU=fundnos.query('mgmt_cd=="ALU"')
THU=fundnos.query('mgmt_cd=="THU"')
TPM=fundnos.query('mgmt_cd=="TPM"')
CTP=fundnos.query('mgmt_cd=="CTP"')
TIM=fundnos.query('mgmt_cd=="TIM"')
TOR=fundnos.query('mgmt_cd=="TOR"')
COU=fundnos.query('mgmt_cd=="COU"')
TRN=fundnos.query('mgmt_cd=="TRN"')
TAI=fundnos.query('mgmt_cd=="TAI"')
TSA=fundnos.query('mgmt_cd=="TSA"')
TCM=fundnos.query('mgmt_cd=="TCM"')
CCS=fundnos.query('mgmt_cd=="CCS"')
OWC=fundnos.query('mgmt_cd=="OWC"')
PSA=fundnos.query('mgmt_cd=="PSA"')
CPC=fundnos.query('mgmt_cd=="CPC"')
AGW=fundnos.query('mgmt_cd=="AGW"')
AKR=fundnos.query('mgmt_cd=="AKR"')
ASC=fundnos.query('mgmt_cd=="ASC"')
LCC=fundnos.query('mgmt_cd=="LCC"')
ALS=fundnos.query('mgmt_cd=="ALS"')
TWB=fundnos.query('mgmt_cd=="TWB"')
UMB=fundnos.query('mgmt_cd=="UMB"')
USA=fundnos.query('mgmt_cd=="USA"')
USF=fundnos.query('mgmt_cd=="USF"')
ARS=fundnos.query('mgmt_cd=="ARS"')
CBN=fundnos.query('mgmt_cd=="CBN"')
LCM=fundnos.query('mgmt_cd=="LCM"')
STN=fundnos.query('mgmt_cd=="STN"')
PSS=fundnos.query('mgmt_cd=="PSS"')
SYO=fundnos.query('mgmt_cd=="SYO"')
GJM=fundnos.query('mgmt_cd=="GJM"')
NSI=fundnos.query('mgmt_cd=="NSI"')
IFM=fundnos.query('mgmt_cd=="IFM"')
SYM=fundnos.query('mgmt_cd=="SYM"')
GLO=fundnos.query('mgmt_cd=="GLO"')
QCM=fundnos.query('mgmt_cd=="QCM"')
SMI=fundnos.query('mgmt_cd=="SMI"')
GPM=fundnos.query('mgmt_cd=="GPM"')
BNH=fundnos.query('mgmt_cd=="BNH"')
SAS=fundnos.query('mgmt_cd=="SAS"')
POL=fundnos.query('mgmt_cd=="POL"')
RIG=fundnos.query('mgmt_cd=="RIG"')
FCL=fundnos.query('mgmt_cd=="FCL"')
ARC=fundnos.query('mgmt_cd=="ARC"')
APP=fundnos.query('mgmt_cd=="APP"')
MIM=fundnos.query('mgmt_cd=="MIM"')
BEC=fundnos.query('mgmt_cd=="BEC"')
CNK=fundnos.query('mgmt_cd=="CNK"')
IMS=fundnos.query('mgmt_cd=="IMS"')
CRW=fundnos.query('mgmt_cd=="CRW"')
DVM=fundnos.query('mgmt_cd=="DVM"')
VIN=fundnos.query('mgmt_cd=="VIN"')
GBG=fundnos.query('mgmt_cd=="GBG"')
OPT=fundnos.query('mgmt_cd=="OPT"')
FIG=fundnos.query('mgmt_cd=="FIG"')
IMR=fundnos.query('mgmt_cd=="IMR"')
RPY=fundnos.query('mgmt_cd=="RPY"')
VFM=fundnos.query('mgmt_cd=="VFM"')
BYC=fundnos.query('mgmt_cd=="BYC"')
VAL=fundnos.query('mgmt_cd=="VAL"')
VAT=fundnos.query('mgmt_cd=="VAT"')
CHU=fundnos.query('mgmt_cd=="CHU"')
VNE=fundnos.query('mgmt_cd=="VNE"')
VNW=fundnos.query('mgmt_cd=="VNW"')
VNP=fundnos.query('mgmt_cd=="VNP"')
ITG=fundnos.query('mgmt_cd=="ITG"')
VLM=fundnos.query('mgmt_cd=="VLM"')
ROX=fundnos.query('mgmt_cd=="ROX"')
WWW=fundnos.query('mgmt_cd=="WWW"')
WAL=fundnos.query('mgmt_cd=="WAL"')
EWM=fundnos.query('mgmt_cd=="EWM"')
WMY=fundnos.query('mgmt_cd=="WMY"')
WEI=fundnos.query('mgmt_cd=="WEI"')
WLD=fundnos.query('mgmt_cd=="WLD"')
FCM=fundnos.query('mgmt_cd=="FCM"')
CKB=fundnos.query('mgmt_cd=="CKB"')
WAM=fundnos.query('mgmt_cd=="WAM"')
RKH=fundnos.query('mgmt_cd=="RKH"')
WBW=fundnos.query('mgmt_cd=="WBW"')
WCF=fundnos.query('mgmt_cd=="WCF"')
DIA=fundnos.query('mgmt_cd=="DIA"')
WTP=fundnos.query('mgmt_cd=="WTP"')
TET=fundnos.query('mgmt_cd=="TET"')
MNC=fundnos.query('mgmt_cd=="MNC"')
FBP=fundnos.query('mgmt_cd=="FBP"')
TLE=fundnos.query('mgmt_cd=="TLE"')
LBT=fundnos.query('mgmt_cd=="LBT"')
DAV=fundnos.query('mgmt_cd=="DAV"')
WLS=fundnos.query('mgmt_cd=="WLS"')
WNT=fundnos.query('mgmt_cd=="WNT"')
WTA=fundnos.query('mgmt_cd=="WTA"')
CSI=fundnos.query('mgmt_cd=="CSI"')
SAN=fundnos.query('mgmt_cd=="SAN"')
VMI=fundnos.query('mgmt_cd=="VMI"')
LCV=fundnos.query('mgmt_cd=="LCV"')
TMI=fundnos.query('mgmt_cd=="TMI"')
OSP=fundnos.query('mgmt_cd=="OSP"')
EIP=fundnos.query('mgmt_cd=="EIP"')
XGX=fundnos.query('mgmt_cd=="XGX"')
DCI=fundnos.query('mgmt_cd=="DCI"')
YAC=fundnos.query('mgmt_cd=="YAC"')
YQA=fundnos.query('mgmt_cd=="YQA"')
EHA=fundnos.query('mgmt_cd=="EHA"')
IVT=fundnos.query('mgmt_cd=="IVT"')
MRV=fundnos.query('mgmt_cd=="MRV"')
PFG=fundnos.query('mgmt_cd=="PFG"')
ECM=fundnos.query('mgmt_cd=="ECM"')
CTL=fundnos.query('mgmt_cd=="CTL"')
VRM=fundnos.query('mgmt_cd=="VRM"')
BRC=fundnos.query('mgmt_cd=="BRC"')
SHI=fundnos.query('mgmt_cd=="SHI"')
XAL=fundnos.query('mgmt_cd=="XAL"')
MBI=fundnos.query('mgmt_cd=="MBI"')
SEM=fundnos.query('mgmt_cd=="SEM"')
ASP=fundnos.query('mgmt_cd=="ASP"')
MZM=fundnos.query('mgmt_cd=="MZM"')
LIM=fundnos.query('mgmt_cd=="LIM"')
GEN=fundnos.query('mgmt_cd=="GEN"')
EAM=fundnos.query('mgmt_cd=="EAM"')
LSA=fundnos.query('mgmt_cd=="LSA"')
FUS=fundnos.query('mgmt_cd=="FUS"')
SCT=fundnos.query('mgmt_cd=="SCT"')
SPA=fundnos.query('mgmt_cd=="SPA"')
AFC=fundnos.query('mgmt_cd=="AFC"')
NCA=fundnos.query('mgmt_cd=="NCA"')
MKA=fundnos.query('mgmt_cd=="MKA"')
PPM=fundnos.query('mgmt_cd=="PPM"')
BEL=fundnos.query('mgmt_cd=="BEL"')
SBF=fundnos.query('mgmt_cd=="SBF"')
ELM=fundnos.query('mgmt_cd=="ELM"')
WFM=fundnos.query('mgmt_cd=="WFM"')
VBM=fundnos.query('mgmt_cd=="VBM"')
BVP=fundnos.query('mgmt_cd=="BVP"')
TMF=fundnos.query('mgmt_cd=="TMF"')
SMD=fundnos.query('mgmt_cd=="SMD"')
RMR=fundnos.query('mgmt_cd=="RMR"')
FQI=fundnos.query('mgmt_cd=="FQI"')
WIA=fundnos.query('mgmt_cd=="WIA"')
WNI=fundnos.query('mgmt_cd=="WNI"')
GCS=fundnos.query('mgmt_cd=="GCS"')
WLT=fundnos.query('mgmt_cd=="WLT"')
LBI=fundnos.query('mgmt_cd=="LBI"')
VTL=fundnos.query('mgmt_cd=="VTL"')
AMG=fundnos.query('mgmt_cd=="AMG"')
DBL=fundnos.query('mgmt_cd=="DBL"')
GRA=fundnos.query('mgmt_cd=="GRA"')
BSM=fundnos.query('mgmt_cd=="BSM"')
GRC=fundnos.query('mgmt_cd=="GRC"')
FRS=fundnos.query('mgmt_cd=="FRS"')
GRT=fundnos.query('mgmt_cd=="GRT"')
ACY=fundnos.query('mgmt_cd=="ACY"')
KYN=fundnos.query('mgmt_cd=="KYN"')
TFP=fundnos.query('mgmt_cd=="TFP"')
CEM=fundnos.query('mgmt_cd=="CEM"')
PUL=fundnos.query('mgmt_cd=="PUL"')
EAA=fundnos.query('mgmt_cd=="EAA"')
KCM=fundnos.query('mgmt_cd=="KCM"')
GEA=fundnos.query('mgmt_cd=="GEA"')
DVS=fundnos.query('mgmt_cd=="DVS"')
SCO=fundnos.query('mgmt_cd=="SCO"')
VIC=fundnos.query('mgmt_cd=="VIC"')
SRC=fundnos.query('mgmt_cd=="SRC"')
IVA=fundnos.query('mgmt_cd=="IVA"')
TGL=fundnos.query('mgmt_cd=="TGL"')
ALH=fundnos.query('mgmt_cd=="ALH"')
HEP=fundnos.query('mgmt_cd=="HEP"')
WFG=fundnos.query('mgmt_cd=="WFG"')
HLD=fundnos.query('mgmt_cd=="HLD"')
CLC=fundnos.query('mgmt_cd=="CLC"')
OXF=fundnos.query('mgmt_cd=="OXF"')
WEG=fundnos.query('mgmt_cd=="WEG"')
LHI=fundnos.query('mgmt_cd=="LHI"')
GLX=fundnos.query('mgmt_cd=="GLX"')
WHV=fundnos.query('mgmt_cd=="WHV"')
JVA=fundnos.query('mgmt_cd=="JVA"')
NEG=fundnos.query('mgmt_cd=="NEG"')
RIA=fundnos.query('mgmt_cd=="RIA"')
RNG=fundnos.query('mgmt_cd=="RNG"')
AQR=fundnos.query('mgmt_cd=="AQR"')
IIQ=fundnos.query('mgmt_cd=="IIQ"')
SFC=fundnos.query('mgmt_cd=="SFC"')
SMU=fundnos.query('mgmt_cd=="SMU"')
CGR=fundnos.query('mgmt_cd=="CGR"')
INA=fundnos.query('mgmt_cd=="INA"')
GLB=fundnos.query('mgmt_cd=="GLB"')
GRL=fundnos.query('mgmt_cd=="GRL"')
INC=fundnos.query('mgmt_cd=="INC"')
EGS=fundnos.query('mgmt_cd=="EGS"')
ADH=fundnos.query('mgmt_cd=="ADH"')
UPR=fundnos.query('mgmt_cd=="UPR"')
CDC=fundnos.query('mgmt_cd=="CDC"')
DOB=fundnos.query('mgmt_cd=="DOB"')
JCE=fundnos.query('mgmt_cd=="JCE"')
CHW=fundnos.query('mgmt_cd=="CHW"')
GWL=fundnos.query('mgmt_cd=="GWL"')
DCM=fundnos.query('mgmt_cd=="DCM"')
RAN=fundnos.query('mgmt_cd=="RAN"')
IMI=fundnos.query('mgmt_cd=="IMI"')
PPA=fundnos.query('mgmt_cd=="PPA"')
TRI=fundnos.query('mgmt_cd=="TRI"')
SFG=fundnos.query('mgmt_cd=="SFG"')
ITA=fundnos.query('mgmt_cd=="ITA"')
BON=fundnos.query('mgmt_cd=="BON"')
QCC=fundnos.query('mgmt_cd=="QCC"')
BAA=fundnos.query('mgmt_cd=="BAA"')
STO=fundnos.query('mgmt_cd=="STO"')
LMI=fundnos.query('mgmt_cd=="LMI"')
ERC=fundnos.query('mgmt_cd=="ERC"')
VEN=fundnos.query('mgmt_cd=="VEN"')
ADC=fundnos.query('mgmt_cd=="ADC"')
AGS=fundnos.query('mgmt_cd=="AGS"')
FSA=fundnos.query('mgmt_cd=="FSA"')
SLM=fundnos.query('mgmt_cd=="SLM"')
JWC=fundnos.query('mgmt_cd=="JWC"')
DBG=fundnos.query('mgmt_cd=="DBG"')
SIG=fundnos.query('mgmt_cd=="SIG"')
BEA=fundnos.query('mgmt_cd=="BEA"')
TAC=fundnos.query('mgmt_cd=="TAC"')
CRX=fundnos.query('mgmt_cd=="CRX"')
ADA=fundnos.query('mgmt_cd=="ADA"')
MGI=fundnos.query('mgmt_cd=="MGI"')
PCL=fundnos.query('mgmt_cd=="PCL"')
XTF=fundnos.query('mgmt_cd=="XTF"')
HWA=fundnos.query('mgmt_cd=="HWA"')
HUB=fundnos.query('mgmt_cd=="HUB"')
SAG=fundnos.query('mgmt_cd=="SAG"')
DGH=fundnos.query('mgmt_cd=="DGH"')
ATI=fundnos.query('mgmt_cd=="ATI"')
JHI=fundnos.query('mgmt_cd=="JHI"')
CNL=fundnos.query('mgmt_cd=="CNL"')
BRI=fundnos.query('mgmt_cd=="BRI"')
AIR=fundnos.query('mgmt_cd=="AIR"')
ALA=fundnos.query('mgmt_cd=="ALA"')
LBC=fundnos.query('mgmt_cd=="LBC"')
SAA=fundnos.query('mgmt_cd=="SAA"')
CMG=fundnos.query('mgmt_cd=="CMG"')
OCM=fundnos.query('mgmt_cd=="OCM"')
SGM=fundnos.query('mgmt_cd=="SGM"')
MFM=fundnos.query('mgmt_cd=="MFM"')
SUM=fundnos.query('mgmt_cd=="SUM"')
CBC=fundnos.query('mgmt_cd=="CBC"')
EPH=fundnos.query('mgmt_cd=="EPH"')
EUP=fundnos.query('mgmt_cd=="EUP"')
ETS=fundnos.query('mgmt_cd=="ETS"')
JHC=fundnos.query('mgmt_cd=="JHC"')
MNP=fundnos.query('mgmt_cd=="MNP"')
DSM=fundnos.query('mgmt_cd=="DSM"')
AKE=fundnos.query('mgmt_cd=="AKE"')
ASI=fundnos.query('mgmt_cd=="ASI"')
RDY=fundnos.query('mgmt_cd=="RDY"')
OOK=fundnos.query('mgmt_cd=="OOK"')
WVC=fundnos.query('mgmt_cd=="WVC"')
CRC=fundnos.query('mgmt_cd=="CRC"')
LCA=fundnos.query('mgmt_cd=="LCA"')
FMX=fundnos.query('mgmt_cd=="FMX"')
DHA=fundnos.query('mgmt_cd=="DHA"')
SCS=fundnos.query('mgmt_cd=="SCS"')
JIM=fundnos.query('mgmt_cd=="JIM"')
ADR=fundnos.query('mgmt_cd=="ADR"')
FTH=fundnos.query('mgmt_cd=="FTH"')
BTS=fundnos.query('mgmt_cd=="BTS"')
VVP=fundnos.query('mgmt_cd=="VVP"')
GFA=fundnos.query('mgmt_cd=="GFA"')
TEF=fundnos.query('mgmt_cd=="TEF"')
POF=fundnos.query('mgmt_cd=="POF"')
MQS=fundnos.query('mgmt_cd=="MQS"')
EVM=fundnos.query('mgmt_cd=="EVM"')
IPM=fundnos.query('mgmt_cd=="IPM"')
AAS=fundnos.query('mgmt_cd=="AAS"')
NTN=fundnos.query('mgmt_cd=="NTN"')
ATM=fundnos.query('mgmt_cd=="ATM"')
EQM=fundnos.query('mgmt_cd=="EQM"')
NMM=fundnos.query('mgmt_cd=="NMM"')
TFM=fundnos.query('mgmt_cd=="TFM"')
DNA=fundnos.query('mgmt_cd=="DNA"')
DLC=fundnos.query('mgmt_cd=="DLC"')
DLF=fundnos.query('mgmt_cd=="DLF"')
SND=fundnos.query('mgmt_cd=="SND"')
NIE=fundnos.query('mgmt_cd=="NIE"')
RWN=fundnos.query('mgmt_cd=="RWN"')
SPF=fundnos.query('mgmt_cd=="SPF"')
OFS=fundnos.query('mgmt_cd=="OFS"')
GIM=fundnos.query('mgmt_cd=="GIM"')
USO=fundnos.query('mgmt_cd=="USO"')
NLM=fundnos.query('mgmt_cd=="NLM"')
STM=fundnos.query('mgmt_cd=="STM"')
CAR=fundnos.query('mgmt_cd=="CAR"')
GDW=fundnos.query('mgmt_cd=="GDW"')
CIF=fundnos.query('mgmt_cd=="CIF"')
PVC=fundnos.query('mgmt_cd=="PVC"')
BTR=fundnos.query('mgmt_cd=="BTR"')
JBK=fundnos.query('mgmt_cd=="JBK"')
RAS=fundnos.query('mgmt_cd=="RAS"')
PCI=fundnos.query('mgmt_cd=="PCI"')
DVL=fundnos.query('mgmt_cd=="DVL"')
CIS=fundnos.query('mgmt_cd=="CIS"')
OSA=fundnos.query('mgmt_cd=="OSA"')
WAC=fundnos.query('mgmt_cd=="WAC"')
ESB=fundnos.query('mgmt_cd=="ESB"')
LGS=fundnos.query('mgmt_cd=="LGS"')
MYM=fundnos.query('mgmt_cd=="MYM"')
PRN=fundnos.query('mgmt_cd=="PRN"')
MIR=fundnos.query('mgmt_cd=="MIR"')
CDW=fundnos.query('mgmt_cd=="CDW"')
MTK=fundnos.query('mgmt_cd=="MTK"')
ALT=fundnos.query('mgmt_cd=="ALT"')
MIW=fundnos.query('mgmt_cd=="MIW"')
PSI=fundnos.query('mgmt_cd=="PSI"')
WED=fundnos.query('mgmt_cd=="WED"')
PTI=fundnos.query('mgmt_cd=="PTI"')
RAC=fundnos.query('mgmt_cd=="RAC"')
GKC=fundnos.query('mgmt_cd=="GKC"')
CLD=fundnos.query('mgmt_cd=="CLD"')
SMH=fundnos.query('mgmt_cd=="SMH"')
SWA=fundnos.query('mgmt_cd=="SWA"')
AVV=fundnos.query('mgmt_cd=="AVV"')
IRC=fundnos.query('mgmt_cd=="IRC"')
BIS=fundnos.query('mgmt_cd=="BIS"')
RVP=fundnos.query('mgmt_cd=="RVP"')
DBN=fundnos.query('mgmt_cd=="DBN"')
HIR=fundnos.query('mgmt_cd=="HIR"')
VCM=fundnos.query('mgmt_cd=="VCM"')
DUC=fundnos.query('mgmt_cd=="DUC"')
RBS=fundnos.query('mgmt_cd=="RBS"')
UMP=fundnos.query('mgmt_cd=="UMP"')
GLG=fundnos.query('mgmt_cd=="GLG"')
GEI=fundnos.query('mgmt_cd=="GEI"')
CWI=fundnos.query('mgmt_cd=="CWI"')
BBW=fundnos.query('mgmt_cd=="BBW"')
BND=fundnos.query('mgmt_cd=="BND"')
LOG=fundnos.query('mgmt_cd=="LOG"')
CCG=fundnos.query('mgmt_cd=="CCG"')
CMT=fundnos.query('mgmt_cd=="CMT"')
WBI=fundnos.query('mgmt_cd=="WBI"')
SGA=fundnos.query('mgmt_cd=="SGA"')
CWC=fundnos.query('mgmt_cd=="CWC"')
RML=fundnos.query('mgmt_cd=="RML"')
USP=fundnos.query('mgmt_cd=="USP"')
BHA=fundnos.query('mgmt_cd=="BHA"')
BST=fundnos.query('mgmt_cd=="BST"')
ASF=fundnos.query('mgmt_cd=="ASF"')
PNL=fundnos.query('mgmt_cd=="PNL"')
ACF=fundnos.query('mgmt_cd=="ACF"')
VLS=fundnos.query('mgmt_cd=="VLS"')
TRC=fundnos.query('mgmt_cd=="TRC"')
FOC=fundnos.query('mgmt_cd=="FOC"')
AOC=fundnos.query('mgmt_cd=="AOC"')
DST=fundnos.query('mgmt_cd=="DST"')
TDW=fundnos.query('mgmt_cd=="TDW"')
OIR=fundnos.query('mgmt_cd=="OIR"')
INI=fundnos.query('mgmt_cd=="INI"')
TWM=fundnos.query('mgmt_cd=="TWM"')
TCL=fundnos.query('mgmt_cd=="TCL"')
TWV=fundnos.query('mgmt_cd=="TWV"')
KNL=fundnos.query('mgmt_cd=="KNL"')
DRB=fundnos.query('mgmt_cd=="DRB"')
TRQ=fundnos.query('mgmt_cd=="TRQ"')
RPG=fundnos.query('mgmt_cd=="RPG"')
ORN=fundnos.query('mgmt_cd=="ORN"')
GHM=fundnos.query('mgmt_cd=="GHM"')
CGD=fundnos.query('mgmt_cd=="CGD"')
EIC=fundnos.query('mgmt_cd=="EIC"')
PSC=fundnos.query('mgmt_cd=="PSC"')
WCI=fundnos.query('mgmt_cd=="WCI"')
CPK=fundnos.query('mgmt_cd=="CPK"')
DBX=fundnos.query('mgmt_cd=="DBX"')
ZEO=fundnos.query('mgmt_cd=="ZEO"')
AGO=fundnos.query('mgmt_cd=="AGO"')
NUI=fundnos.query('mgmt_cd=="NUI"')
TRT=fundnos.query('mgmt_cd=="TRT"')
HNP=fundnos.query('mgmt_cd=="HNP"')
CFS=fundnos.query('mgmt_cd=="CFS"')
BGF=fundnos.query('mgmt_cd=="BGF"')
CLO=fundnos.query('mgmt_cd=="CLO"')
LCF=fundnos.query('mgmt_cd=="LCF"')
SIF=fundnos.query('mgmt_cd=="SIF"')
LGV=fundnos.query('mgmt_cd=="LGV"')
CNR=fundnos.query('mgmt_cd=="CNR"')
MDS=fundnos.query('mgmt_cd=="MDS"')
GPS=fundnos.query('mgmt_cd=="GPS"')
MSC=fundnos.query('mgmt_cd=="MSC"')
VHA=fundnos.query('mgmt_cd=="VHA"')
WFD=fundnos.query('mgmt_cd=="WFD"')
ALR=fundnos.query('mgmt_cd=="ALR"')
PDN=fundnos.query('mgmt_cd=="PDN"')
GRF=fundnos.query('mgmt_cd=="GRF"')
CKW=fundnos.query('mgmt_cd=="CKW"')
GRE=fundnos.query('mgmt_cd=="GRE"')
DRG=fundnos.query('mgmt_cd=="DRG"')
APN=fundnos.query('mgmt_cd=="APN"')
DGI=fundnos.query('mgmt_cd=="DGI"')
CPE=fundnos.query('mgmt_cd=="CPE"')
WAS=fundnos.query('mgmt_cd=="WAS"')
FFM=fundnos.query('mgmt_cd=="FFM"')
RTS=fundnos.query('mgmt_cd=="RTS"')
CRT=fundnos.query('mgmt_cd=="CRT"')
GNS=fundnos.query('mgmt_cd=="GNS"')
PIA=fundnos.query('mgmt_cd=="PIA"')
STW=fundnos.query('mgmt_cd=="STW"')
ASD=fundnos.query('mgmt_cd=="ASD"')
APW=fundnos.query('mgmt_cd=="APW"')
DLX=fundnos.query('mgmt_cd=="DLX"')
GPG=fundnos.query('mgmt_cd=="GPG"')
BPV=fundnos.query('mgmt_cd=="BPV"')
PGC=fundnos.query('mgmt_cd=="PGC"')
TWL=fundnos.query('mgmt_cd=="TWL"')
PCA=fundnos.query('mgmt_cd=="PCA"')
TRX=fundnos.query('mgmt_cd=="TRX"')
JPI=fundnos.query('mgmt_cd=="JPI"')
RGT=fundnos.query('mgmt_cd=="RGT"')
MOR=fundnos.query('mgmt_cd=="MOR"')
GPA=fundnos.query('mgmt_cd=="GPA"')
DMA=fundnos.query('mgmt_cd=="DMA"')
WBX=fundnos.query('mgmt_cd=="WBX"')
RJO=fundnos.query('mgmt_cd=="RJO"')
MTE=fundnos.query('mgmt_cd=="MTE"')
NST=fundnos.query('mgmt_cd=="NST"')
HYC=fundnos.query('mgmt_cd=="HYC"')
TCH=fundnos.query('mgmt_cd=="TCH"')
HAC=fundnos.query('mgmt_cd=="HAC"')
DXH=fundnos.query('mgmt_cd=="DXH"')
GRV=fundnos.query('mgmt_cd=="GRV"')
CWL=fundnos.query('mgmt_cd=="CWL"')
JAG=fundnos.query('mgmt_cd=="JAG"')
VMY=fundnos.query('mgmt_cd=="VMY"')
KIG=fundnos.query('mgmt_cd=="KIG"')
NWP=fundnos.query('mgmt_cd=="NWP"')
ICR=fundnos.query('mgmt_cd=="ICR"')
SCF=fundnos.query('mgmt_cd=="SCF"')
HGH=fundnos.query('mgmt_cd=="HGH"')
SNC=fundnos.query('mgmt_cd=="SNC"')
IVR=fundnos.query('mgmt_cd=="IVR"')
SCP=fundnos.query('mgmt_cd=="SCP"')
HZN=fundnos.query('mgmt_cd=="HZN"')
LHN=fundnos.query('mgmt_cd=="LHN"')
OFC=fundnos.query('mgmt_cd=="OFC"')
KMC=fundnos.query('mgmt_cd=="KMC"')
NWF=fundnos.query('mgmt_cd=="NWF"')
SMG=fundnos.query('mgmt_cd=="SMG"')
MGN=fundnos.query('mgmt_cd=="MGN"')
WOA=fundnos.query('mgmt_cd=="WOA"')
PIP=fundnos.query('mgmt_cd=="PIP"')
MZC=fundnos.query('mgmt_cd=="MZC"')
AUT=fundnos.query('mgmt_cd=="AUT"')
IFP=fundnos.query('mgmt_cd=="IFP"')
HMC=fundnos.query('mgmt_cd=="HMC"')
THB=fundnos.query('mgmt_cd=="THB"')
RKY=fundnos.query('mgmt_cd=="RKY"')
HGN=fundnos.query('mgmt_cd=="HGN"')
CCV=fundnos.query('mgmt_cd=="CCV"')
MTN=fundnos.query('mgmt_cd=="MTN"')
ACP=fundnos.query('mgmt_cd=="ACP"')
PSG=fundnos.query('mgmt_cd=="PSG"')
MFR=fundnos.query('mgmt_cd=="MFR"')
CWP=fundnos.query('mgmt_cd=="CWP"')
RNH=fundnos.query('mgmt_cd=="RNH"')
AVC=fundnos.query('mgmt_cd=="AVC"')
UBG=fundnos.query('mgmt_cd=="UBG"')
JBA=fundnos.query('mgmt_cd=="JBA"')
LNB=fundnos.query('mgmt_cd=="LNB"')
SLP=fundnos.query('mgmt_cd=="SLP"')
KLN=fundnos.query('mgmt_cd=="KLN"')
LWI=fundnos.query('mgmt_cd=="LWI"')
APX=fundnos.query('mgmt_cd=="APX"')
LGN=fundnos.query('mgmt_cd=="LGN"')
BGH=fundnos.query('mgmt_cd=="BGH"')
BWM=fundnos.query('mgmt_cd=="BWM"')
AAV=fundnos.query('mgmt_cd=="AAV"')
CLE=fundnos.query('mgmt_cd=="CLE"')
ACO=fundnos.query('mgmt_cd=="ACO"')
SWN=fundnos.query('mgmt_cd=="SWN"')
HMS=fundnos.query('mgmt_cd=="HMS"')
CAI=fundnos.query('mgmt_cd=="CAI"')
RBP=fundnos.query('mgmt_cd=="RBP"')
SLT=fundnos.query('mgmt_cd=="SLT"')
PPR=fundnos.query('mgmt_cd=="PPR"')
SMN=fundnos.query('mgmt_cd=="SMN"')
BZC=fundnos.query('mgmt_cd=="BZC"')
VPX=fundnos.query('mgmt_cd=="VPX"')
WKE=fundnos.query('mgmt_cd=="WKE"')
BCP=fundnos.query('mgmt_cd=="BCP"')
TYL=fundnos.query('mgmt_cd=="TYL"')
RAY=fundnos.query('mgmt_cd=="RAY"')
SGL=fundnos.query('mgmt_cd=="SGL"')
DMS=fundnos.query('mgmt_cd=="DMS"')
FWC=fundnos.query('mgmt_cd=="FWC"')
DPS=fundnos.query('mgmt_cd=="DPS"')
KKR=fundnos.query('mgmt_cd=="KKR"')
CNM=fundnos.query('mgmt_cd=="CNM"')
SNK=fundnos.query('mgmt_cd=="SNK"')
PUR=fundnos.query('mgmt_cd=="PUR"')
FGM=fundnos.query('mgmt_cd=="FGM"')
KOR=fundnos.query('mgmt_cd=="KOR"')
ELS=fundnos.query('mgmt_cd=="ELS"')
EUD=fundnos.query('mgmt_cd=="EUD"')
GLC=fundnos.query('mgmt_cd=="GLC"')
BCI=fundnos.query('mgmt_cd=="BCI"')
EVA=fundnos.query('mgmt_cd=="EVA"')
YCG=fundnos.query('mgmt_cd=="YCG"')
GHF=fundnos.query('mgmt_cd=="GHF"')
PSM=fundnos.query('mgmt_cd=="PSM"')
JKP=fundnos.query('mgmt_cd=="JKP"')
RVB=fundnos.query('mgmt_cd=="RVB"')
CGN=fundnos.query('mgmt_cd=="CGN"')
WPN=fundnos.query('mgmt_cd=="WPN"')
FPR=fundnos.query('mgmt_cd=="FPR"')
BLV=fundnos.query('mgmt_cd=="BLV"')
ABM=fundnos.query('mgmt_cd=="ABM"')
BRD=fundnos.query('mgmt_cd=="BRD"')
CCF=fundnos.query('mgmt_cd=="CCF"')
LJM=fundnos.query('mgmt_cd=="LJM"')
NPA=fundnos.query('mgmt_cd=="NPA"')
HRV=fundnos.query('mgmt_cd=="HRV"')
LYR=fundnos.query('mgmt_cd=="LYR"')
ADN=fundnos.query('mgmt_cd=="ADN"')
AMH=fundnos.query('mgmt_cd=="AMH"')
MIP=fundnos.query('mgmt_cd=="MIP"')
AUR=fundnos.query('mgmt_cd=="AUR"')
MKC=fundnos.query('mgmt_cd=="MKC"')
APR=fundnos.query('mgmt_cd=="APR"')
LMD=fundnos.query('mgmt_cd=="LMD"')
DRP=fundnos.query('mgmt_cd=="DRP"')
AMW=fundnos.query('mgmt_cd=="AMW"')
CMC=fundnos.query('mgmt_cd=="CMC"')
GTR=fundnos.query('mgmt_cd=="GTR"')
MSG=fundnos.query('mgmt_cd=="MSG"')
RDG=fundnos.query('mgmt_cd=="RDG"')
GWC=fundnos.query('mgmt_cd=="GWC"')
ANF=fundnos.query('mgmt_cd=="ANF"')
NFA=fundnos.query('mgmt_cd=="NFA"')
VIS=fundnos.query('mgmt_cd=="VIS"')
GTY=fundnos.query('mgmt_cd=="GTY"')
KFA=fundnos.query('mgmt_cd=="KFA"')
SBH=fundnos.query('mgmt_cd=="SBH"')
LCL=fundnos.query('mgmt_cd=="LCL"')
EQI=fundnos.query('mgmt_cd=="EQI"')
VAM=fundnos.query('mgmt_cd=="VAM"')
EVC=fundnos.query('mgmt_cd=="EVC"')
CPL=fundnos.query('mgmt_cd=="CPL"')
BSA=fundnos.query('mgmt_cd=="BSA"')
ARA=fundnos.query('mgmt_cd=="ARA"')
TUA=fundnos.query('mgmt_cd=="TUA"')
DIM=fundnos.query('mgmt_cd=="DIM"')
WAV=fundnos.query('mgmt_cd=="WAV"')
HTC=fundnos.query('mgmt_cd=="HTC"')
LAP=fundnos.query('mgmt_cd=="LAP"')
SVP=fundnos.query('mgmt_cd=="SVP"')
CFP=fundnos.query('mgmt_cd=="CFP"')
WPA=fundnos.query('mgmt_cd=="WPA"')
STB=fundnos.query('mgmt_cd=="STB"')
SCV=fundnos.query('mgmt_cd=="SCV"')
KFC=fundnos.query('mgmt_cd=="KFC"')
OSI=fundnos.query('mgmt_cd=="OSI"')
FDS=fundnos.query('mgmt_cd=="FDS"')
GVC=fundnos.query('mgmt_cd=="GVC"')
BFS=fundnos.query('mgmt_cd=="BFS"')
HCI=fundnos.query('mgmt_cd=="HCI"')
WSG=fundnos.query('mgmt_cd=="WSG"')
KGI=fundnos.query('mgmt_cd=="KGI"')
RSQ=fundnos.query('mgmt_cd=="RSQ"')
LKP=fundnos.query('mgmt_cd=="LKP"')
RDW=fundnos.query('mgmt_cd=="RDW"')
WBS=fundnos.query('mgmt_cd=="WBS"')
CRP=fundnos.query('mgmt_cd=="CRP"')
REQ=fundnos.query('mgmt_cd=="REQ"')
SKB=fundnos.query('mgmt_cd=="SKB"')
SRO=fundnos.query('mgmt_cd=="SRO"')
BKC=fundnos.query('mgmt_cd=="BKC"')
CFD=fundnos.query('mgmt_cd=="CFD"')
BUS=fundnos.query('mgmt_cd=="BUS"')
RKF=fundnos.query('mgmt_cd=="RKF"')
IHC=fundnos.query('mgmt_cd=="IHC"')
MTG=fundnos.query('mgmt_cd=="MTG"')
GTX=fundnos.query('mgmt_cd=="GTX"')
OTT=fundnos.query('mgmt_cd=="OTT"')
CPG=fundnos.query('mgmt_cd=="CPG"')
BAL=fundnos.query('mgmt_cd=="BAL"')
BCF=fundnos.query('mgmt_cd=="BCF"')
CAN=fundnos.query('mgmt_cd=="CAN"')
DPF=fundnos.query('mgmt_cd=="DPF"')
QCI=fundnos.query('mgmt_cd=="QCI"')
PER=fundnos.query('mgmt_cd=="PER"')
CVR=fundnos.query('mgmt_cd=="CVR"')
LCG=fundnos.query('mgmt_cd=="LCG"')
FDP=fundnos.query('mgmt_cd=="FDP"')
RVD=fundnos.query('mgmt_cd=="RVD"')
CFM=fundnos.query('mgmt_cd=="CFM"')
HOR=fundnos.query('mgmt_cd=="HOR"')
HZC=fundnos.query('mgmt_cd=="HZC"')
NOR=fundnos.query('mgmt_cd=="NOR"')
LQS=fundnos.query('mgmt_cd=="LQS"')
NFG=fundnos.query('mgmt_cd=="NFG"')
SBE=fundnos.query('mgmt_cd=="SBE"')
POI=fundnos.query('mgmt_cd=="POI"')
WSC=fundnos.query('mgmt_cd=="WSC"')
CDM=fundnos.query('mgmt_cd=="CDM"')
VIR=fundnos.query('mgmt_cd=="VIR"')
CXA=fundnos.query('mgmt_cd=="CXA"')
SBR=fundnos.query('mgmt_cd=="SBR"')
NFR=fundnos.query('mgmt_cd=="NFR"')
SPC=fundnos.query('mgmt_cd=="SPC"')
KKM=fundnos.query('mgmt_cd=="KKM"')
RCN=fundnos.query('mgmt_cd=="RCN"')
CUP=fundnos.query('mgmt_cd=="CUP"')
RLL=fundnos.query('mgmt_cd=="RLL"')
CRY=fundnos.query('mgmt_cd=="CRY"')
ABB=fundnos.query('mgmt_cd=="ABB"')
APH=fundnos.query('mgmt_cd=="APH"')
HWD=fundnos.query('mgmt_cd=="HWD"')
MLT=fundnos.query('mgmt_cd=="MLT"')
MAA=fundnos.query('mgmt_cd=="MAA"')
ATS=fundnos.query('mgmt_cd=="ATS"')
NSA=fundnos.query('mgmt_cd=="NSA"')
JAL=fundnos.query('mgmt_cd=="JAL"')
EDA=fundnos.query('mgmt_cd=="EDA"')
SOR=fundnos.query('mgmt_cd=="SOR"')
AKI=fundnos.query('mgmt_cd=="AKI"')
CCT=fundnos.query('mgmt_cd=="CCT"')
MAX=fundnos.query('mgmt_cd=="MAX"')
TCG=fundnos.query('mgmt_cd=="TCG"')
AAD=fundnos.query('mgmt_cd=="AAD"')
EMP=fundnos.query('mgmt_cd=="EMP"')
LDM=fundnos.query('mgmt_cd=="LDM"')
CHC=fundnos.query('mgmt_cd=="CHC"')
AXT=fundnos.query('mgmt_cd=="AXT"')
EFC=fundnos.query('mgmt_cd=="EFC"')
CFR=fundnos.query('mgmt_cd=="CFR"')
UCF=fundnos.query('mgmt_cd=="UCF"')
IAG=fundnos.query('mgmt_cd=="IAG"')
GUR=fundnos.query('mgmt_cd=="GUR"')
VRT=fundnos.query('mgmt_cd=="VRT"')
OKT=fundnos.query('mgmt_cd=="OKT"')
VDM=fundnos.query('mgmt_cd=="VDM"')
RSA=fundnos.query('mgmt_cd=="RSA"')
PCG=fundnos.query('mgmt_cd=="PCG"')
GGP=fundnos.query('mgmt_cd=="GGP"')
ATT=fundnos.query('mgmt_cd=="ATT"')
TRR=fundnos.query('mgmt_cd=="TRR"')
WLM=fundnos.query('mgmt_cd=="WLM"')

# %%
AFD
# Out:
#        summary_period2  crsp_fundno  \
# 7688                AQ         3689
# 17185               AQ         4717
# 17186               AQ         4717
# 17195               AQ         4717
# 17200               AQ         4718
# 17210               AQ         4718
# 17215               AQ         4719
# 17224               AQ         4719
# 17229               AQ         4720
# 17236               AQ         4720
# 17238               AQ         4720
# 17243               AQ         4721
# 17251               AQ         4721
# 17256               AQ         4722
# 17264               AQ         4722
# 17269               AQ         4723
# 17277               AQ         4723
# 17282               AQ         4724
# 17290               AQ         4724
# 17295               AQ         4725
# 17303               AQ         4725
# 17308               AQ         4726
# 17316               AQ         4726
# 17321               AQ         4727
# 17329               AQ         4727
# ...

# %%
#match_func = lambda x: get_close_matches(x, van.String, 3, 0.8)
#van['crsp_fundno'] = VAN['fund_name'].apply(match_func)

van
# Out:
#        Unnamed: 0                          ACK ID Party-in-Interest  \
# 551           551  20140617160329P030391354851001               NaN
# 552           552  20140617160329P030391354851001               NaN
# 553           553  20140617160329P030391354851001               NaN
# 554           554  20140617160329P030391354851001               NaN
# 555           555  20140617160329P030391354851001               NaN
# 556           556  20140617160329P030391354851001               NaN
# 557           557  20140617160329P030391354851001               NaN
# 667           667  20140708153608P040029355489001               NaN
# 676           676  20140712154009P040011800015001               NaN
# 677           677  20140712154009P040011800015001               NaN
# 678           678  20140712154009P040011800015001               NaN
# 680           680  20140712154009P040011800015001               NaN
# 682           682  20140712154009P040011800015001               NaN
# ...

# %%
van['crsp_fundno']=""
van
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#        Unnamed: 0                          ACK ID Party-in-Interest  \
# 551           551  20140617160329P030391354851001               NaN
# 552           552  20140617160329P030391354851001               NaN
# 553           553  20140617160329P030391354851001               NaN
# 554           554  20140617160329P030391354851001               NaN
# 555           555  20140617160329P030391354851001               NaN
# 556           556  20140617160329P030391354851001               NaN
# 557           557  20140617160329P030391354851001               NaN
# ...

# %%
vanguardlist = list(VAN.fund_name)
vanguardlist
# Out:
# ['Vanguard Montgomery Funds: Vanguard Market Neutral Fund; Investor Shs',
#  'Vanguard Montgomery Funds: Vanguard Market Neutral Fund; Inst Class',
#  'Vanguard Specialized Funds: Vanguard Energy Fund',
#  'Vanguard Specialized Funds: Vanguard Energy Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard Gold and Precious Metals Fund',
#  'Vanguard Specialized Funds: Vanguard Precious Metals Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard Precious Metals & Mining Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard Health Care Fund',
#  'Vanguard Specialized Funds: Vanguard Health Care Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard Utilities Income Fund',
#  'Vanguard Specialized Funds: Vanguard Utilities Income Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard Dividend Growth Fund; Investor Shares',
#  'Vanguard Specialized Funds: Vanguard REIT Index Fund',
# ...

# %%
van.String[65187]
# Out:
# 'VANGUARD ADMIRAL WINDSOR II  MUTUAL FUND'

# %%
from difflib import get_close_matches
get_close_matches(van.String[65187],vanguardlist,10, 0.2)
# Out:
# ['Vanguard PRIMECAP Fund',
#  'Vanguard PRIMECAP Fund; Admiral Shares',
#  'Vanguard PRIMECAP Fund; Investor Shares',
#  'Vanguard Wellesley Income Fund',
#  'Vanguard Asset Allocation Fund']

# %%
from difflib import SequenceMatcher as SM
maxratio = 0
beststring = ""
for i in vanguardlist:
    if SM(None, van.String[65187],vanguardlist[0]).ratio() > maxratio:
        maxratio = SM(None, van.String[65187],vanguardlist[0]).ratio()
        beststring = i

# %%
maxratio
# Out:
# 0.11009174311926606

# %%
van.String[677]
# Out:
# 'VANGUARD TOTAL BOND MARKET INDEX FUND SIGNAL CLASS  MUTUAL FUND, 124,363 SHARES'

# %%
AFD.to_csv('CRSP_AFD.csv')
afd1=mf1[mf1.familyname.str.contains("AFD")==True]
afd1.to_csv('401k_afd.csv')

# %%
VAN.shape
van=mf1.query(' familyname=="VAN"')
van1=mf1[mf1.familyname.str.contains("VAN")==True]

# %%
VAN.to_csv('CRSP_van.csv')
van1.to_csv('401k_van.csv')

# %%
van.shape
# Out:
# (2498, 12)
