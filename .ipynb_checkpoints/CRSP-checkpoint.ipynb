# %%
from datetime import datetime
start_time = datetime.now()
import pandas as pd
import numpy as np
import csv
import os
path = "/Users/michaelwymbs/Documents/wahal"
os.chdir(path)
df1 = pd.read_csv('df1.csv')
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
crspraw = pd.read_csv('crspraw.csv')
crspraw['range0'] = 0
for i in range(0,crspraw.shape[0]):
    crspraw.range0[i] = i
crsptbl=df1.query(' dbname=="crsp"')
crsptbl['PERMNO']=""
crsptbl1 = crsptbl
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
a=crsptbl['range']
b=list(a)
aa=crsptbl['String']
bb=list(aa)
#for i in range(0,len(bb)):
dict1 = {}
dict2 = {}
for i in range(0,len(b)):
    dict1[b[i]]=bb[i]
    dict2[b[i]]=[]

# %%
listdict = []

for i in range(0,crspraw.shape[0]):
    if i % 100 ==0:
        print datetime.now() 
    for j in range(0,len(b)):
        if crspraw.loc[i,'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], crspraw.loc[i,'PERMNO']))
# Out:
# 2015-11-14 17:47:49.951887
# 2015-11-14 17:51:36.542868
# 2015-11-14 17:55:20.720856
# 2015-11-14 17:59:05.521801
# 2015-11-14 18:02:49.629573
# 2015-11-14 18:06:34.609142
# 2015-11-14 18:10:18.472666
# 2015-11-14 18:14:00.241254
# 2015-11-14 18:17:43.102079
# 2015-11-14 18:21:27.538286
# 2015-11-14 18:25:09.024379
# 2015-11-14 18:28:50.735357
# 2015-11-14 18:32:32.345203
# 2015-11-14 18:36:14.628667
# 2015-11-14 18:39:57.342971
# 2015-11-14 18:43:37.255309
# 2015-11-14 18:47:17.638521
# 2015-11-14 18:50:58.878827
# 2015-11-14 18:54:38.527831
# 2015-11-14 18:58:18.402187
# 2015-11-14 19:01:58.939644
# 2015-11-14 19:05:38.630012
# 2015-11-14 19:09:19.326429
# 2015-11-14 19:12:59.294836
# 2015-11-14 19:16:39.769680
# 2015-11-14 19:20:20.050525
# 2015-11-14 19:23:58.801171
# 2015-11-14 19:27:37.841259
# 2015-11-14 19:31:18.486341
# 2015-11-14 19:34:59.612592
# 2015-11-14 19:38:44.359757
# 2015-11-14 19:42:23.835147
# 2015-11-14 19:46:02.709553
# 2015-11-14 19:49:43.302782
# ...

# %%
intl0 = crspraw[(crspraw.COMNAM.str.contains("INTL")==True)]
for i in intl0['range0']:
    intl0.COMNAM[i] = intl0.COMNAM[i].replace(" INTL","")
for i in intl0['range0']:
    for j in range(0,len(b)):
        if intl0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], intl0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data. 
corp0 = crspraw[(crspraw.COMNAM.str.contains("CORP")==True)]
corp0 = corp0[(corp0.PERMNO != 59950)]#There is an entry for "M CORP" which then matches for 
#any CRSP name that contains the letter M - removing this 
for i in corp0['range0']:
    corp0.COMNAM[i] = corp0.COMNAM[i].replace(" CORP","")
for i in corp0['range0']:
    for j in range(0,len(b)):
        if corp0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], corp0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data. 
inc0 = crspraw[(crspraw.COMNAM.str.contains("INC")==True)]
for i in inc0['range0']:
    inc0.COMNAM[i] = inc0.COMNAM[i].replace(" INC","")
for i in inc0['range0']:
    for j in range(0,len(b)):
        if inc0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], inc0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data.
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#intl0 = crspraw[(crspraw.COMNAM.str.contains("INTL")==True)]
#for i in intl0['range0']:
#    intl0.COMNAM[i] = intl0.COMNAM[i].replace(" INTL","")
inc0
# Out:
#                              COMNAM  PERMNO TSYMBOL  range0
# 0             OPTIMUM MANUFACTURING   10000   OMFGA       0
# 1             OPTIMUM MANUFACTURING   10000   OMFAC       1
# 3                       ENERGY WEST   10001    EWST       3
# 4                       ENERGY WEST   10001   EWSTE       4
# 5                       ENERGY WEST   10001   EWSTD       5
# 6                            ENERGY   10001    EGAS       6
# 7                       GAS NATURAL   10001    EGAS       7
# 9      SOUTH ALABAMA BANCORPORATION   10002    SABC       9
# 10        BANCTRUST FINANCIAL GROUP   10002    BTFG      10
# 12                  CLOSE OUTS PLUS   10004    CLSO      12
# 13         WESTERN ENERGY RESOURCES   10005    WERC      13
# 15                 A C F INDUSTRIES   10006     NaN      15
# 16                        SHAREDATA   10007    SDIC      16
# 17                        SHAREDATA   10007   SDICV      17
# 18                        SHAREDATA   10007   SDICE      18
# ...

# %%
from collections import defaultdict
d = defaultdict(list)
for key, permno in listdict:
    d[key].append(permno)

# %%
for i in d.keys():
    d[i] = list(set(d.get(i))) #remove duplicates
dictionarydf = pd.DataFrame({'range' : d.keys() , 'PERMNO' : d.values() })
for i in range(0,dictionarydf.shape[0]):#FIX THIS 
    crsptbl.PERMNO[int(dictionarydf.range[i])]=",".join(dictionarydf.PERMNO[i])
crsptbl.PERMNO.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-22b33ff0cf3a> in <module>()
#       3 dictionarydf = pd.DataFrame({'range' : d.keys() , 'PERMNO' : d.values() })
#       4 for i in range(0,dictionarydf.shape[0]):#FIX THIS
# ----> 5     crsptbl.PERMNO[int(dictionarydf.range[i])]=",".join(dictionarydf.PERMNO[i])
#       6 crsptbl.PERMNO.value_counts()
#
# TypeError: sequence item 0: expected string, numpy.int64 found

# %% [markdown]
# dictionarydf

# %%
for i in inc0.range[:]:
    for j in range(0,len(b)):
        if inc0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], inc0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-814433988ad3> in <module>()
#       1 for i in inc0.range[:]:
#       2     for j in range(0,len(b)):
# ----> 3         if inc0.loc[int(i),'COMNAM'] in dict1[b[j]]:
#       4             listdict.append((b[j], inc0.loc[int(i),'PERMNO']))
#       5             #make sure to put int(i) in your index when you are subsetting data.
#
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1185     def __getitem__(self, key):
#    1186         if type(key) is tuple:
# -> 1187             return self._getitem_tuple(key)
#    1188         else:
#    1189             return self._getitem_axis(key, axis=0)
#
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     698     def _getitem_tuple(self, tup):
# ...

# %%
corp0 = crspraw[(crspraw.COMNAM.str.contains("CORP")==True)]
corp0 = corp0[(corp0.PERMNO != 59950)]#There is an entry for "M CORP" which then matches for 
#any CRSP name that contains the letter M - removing this 
for i in corp0['range']:
    corp0.COMNAM[i] = corp0.COMNAM[i].replace(" CORP","")
for i in corp0.range[:]:
    for j in range(0,len(b)):
        if corp0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], corp0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data.
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
intl0 = crspraw[(crspraw.COMNAM.str.contains("INTL")==True)]
for i in intl0['range']:
    intl0.COMNAM[i] = intl0.COMNAM[i].replace(" INTL","")
for i in intl0.range[:]:
    for j in range(0,len(b)):
        if intl0.loc[int(i),'COMNAM'] in dict1[b[j]]:
            listdict.append((b[j], intl0.loc[int(i),'PERMNO']))
            #make sure to put int(i) in your index when you are subsetting data.
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
dictionarydf = pd.DataFrame({'range' : d.keys() , 'PERMNO' : d.values() })
for i in range(0,dictionarydf.shape[0]):
    print dictionarydf.PERMNO[i]
# Out:
# [12300, 59950]
# [84788, 59950]
# [59950, 50391]
# [14593, 92618, 59950]
# [84338]
# [59950]
# [76592]
# [59950]
# [59950]
# [24459]
# [59950]
# [89179, 59950]
# [86580]
# [59950]
# [26737, 83844, 11973, 59950]
# [20482]
# [83976, 10533, 59950, 87101]
# [87055]
# [59950]
# [59950]
# [90379, 89301, 59950]
# [14542, 59950, 90319]
# [78916, 55271]
# [12230, 59950]
# [34518, 59950]
# [62498, 84283, 13830, 59950]
# [66800, 10313, 34518, 59950]
# [34518, 81925, 59950]
# [81598, 59950]
# [59950]
# [17961, 59950, 68081]
# [45604, 59950, 19351]
# [59950]
# [69287, 62092, 59950, 86928, 89212, 77150]
# [59950]
# [59950]
# [17523, 59950]
# [63781, 59950]
# [90490, 92987, 59950]
# [59950, 68591]
# [59950]
# [59950]
# [10001, 59950]
# [91493, 59950]
# [59950]
# [59950]
# [78859, 59950]
# [59950]
# [59950]
# [59950]
# [14593, 59950]
# [75326, 59950]
# [59950]
# [59950]
# [59950]
# [77659, 87101, 59950]
# [85946, 59950]
# [59950]
# [47002, 59950]
# [87101, 59950]
# [18542, 59950]
# [92034, 59950]
# ...

# %%
#dictionarydf.to_csv('crsptbl1.csv')
#print crsptbl.PERMNO.loc[[40998]]
for i in range(0,dictionarydf.shape[0]):#FIX THIS 
    crsptbl.PERMNO[int(dictionarydf.range[i])]
dictionarydf
# Out:
#                             PERMNO  range
# 0                      12300,59950  58921
# 1                      84788,59950  28915
# 2                      59950,50391  64172
# 3                14593,92618,59950  62807
# 4                            84338   9560
# 5                            59950  49170
# 6                            76592  13094
# 7                            59950  13148
# 8                            59950  62685
# 9                            24459  41191
# 10                         [59950]  57558
# 11                  [89179, 59950]   5390
# 12                         [86580]  35898
# 13                         [59950]  25097
# 14    [26737, 83844, 11973, 59950]  40998
# 15                         [20482]  21852
# 16    [83976, 10533, 59950, 87101]  21853
# 17                         [87055]  34032
# 18                         [59950]   5183
# 19                         [59950]  62814
# 20           [90379, 89301, 59950]  61449
# ...

# %%
for i in range(0,10):#dictionarydf.shape[0]):#FIX THIS 

    crsptbl.PERMNO[int(dictionarydf.range[i])]=",".join(dictionarydf.PERMNO[i])
#crsptbl.PERMNO.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-268-702b677e9706> in <module>()
#       1 for i in range(0,10):#dictionarydf.shape[0]):#FIX THIS
#       2
# ----> 3     crsptbl.PERMNO[int(dictionarydf.range[i])]=",".join(dictionarydf.PERMNO[i])
#       4 #crsptbl.PERMNO.value_counts()
#
# TypeError: sequence item 0: expected string, numpy.int64 found

# %%
inc = crspraw[(crspraw.COMNAM.str.contains("INC")==True)]
for i in range(0,inc.shape[0]):
    inc[i] = inc.COMNAM[i].replace(' INC','')
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-03cd20bca511> in <module>()
#       1 inc = crspraw[(crspraw.COMNAM.str.contains("INC")==True)]
#       2 for i in range(0,inc.shape[0]):
# ----> 3     inc[i] = inc.COMNAM[i].replace(' INC','')
#
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     519     def __getitem__(self, key):
#     520         try:
# ...

# %%
inc = crspraw[(crspraw.COMNAM.str.contains("INC")==True)]
v = []
v.append(inc.COMNAM[0].replace(" INC",""))
v.append(inc.COMNAM[1].replace(" INC",""))
#for i in range(0,inc.shape[0]):
#    v.append(inc.COMNAM[i].replace(" INC",""))
v
# Out:
# ['OPTIMUM MANUFACTURING', 'OPTIMUM MANUFACTURING']

# %%
v.append(inc.COMNAM[2].replace(" INC",""))
#for i in range(0,inc.shape[0]):
#    v.append(inc.COMNAM[i].replace(" INC",""))
v
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-f102b2456f8a> in <module>()
# ----> 1 v.append(inc.COMNAM[2].replace(" INC",""))
#       2 #for i in range(0,inc.shape[0]):
#       3 #    v.append(inc.COMNAM[i].replace(" INC",""))
#       4 v
#
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     519     def __getitem__(self, key):
#     520         try:
# --> 521             result = self.index.get_value(self, key)
#     522
#     523             if not np.isscalar(result):
#
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1593
#    1594         try:
# -> 1595             return self._engine.get_value(s, k)
#    1596         except KeyError as e1:
# ...

# %%
for i in crspraw.shape[0]):
    crspraw.loc[i,'range'] = int(i)

# %%
inc = crspraw[(crspraw.COMNAM.str.contains("INC")==True)]
v = []
inc2= inc

# %%
for i in inc['range']:
    inc2.COMNAM[i] = inc.COMNAM[i].replace(" INC","")
    #v.append(inc.COMNAM[i].replace(" INC",""))
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/pandas/core/series.py:664: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def bucket2(dfcat, dfleft, SearchStr, dbnameStr, searchcol='String',fillcol='PERMNO'):
    a=dfleft[dfleft[searchcol].str.contains(SearchStr)==True]
    for i in a['range']:
        b = str(dfcat.loc[i,fillcol])
        dfcat.loc[i,fillcol] = b +","+  str(dbnameStr)
# Out:
#                              COMNAM  PERMNO TSYMBOL  range
# 0             OPTIMUM MANUFACTURING   10000   OMFGA      0
# 1             OPTIMUM MANUFACTURING   10000   OMFAC      1
# 3                       ENERGY WEST   10001    EWST      3
# 4                       ENERGY WEST   10001   EWSTE      4
# 5                       ENERGY WEST   10001   EWSTD      5
# 6                            ENERGY   10001    EGAS      6
# 7                       GAS NATURAL   10001    EGAS      7
# 9      SOUTH ALABAMA BANCORPORATION   10002    SABC      9
# 10        BANCTRUST FINANCIAL GROUP   10002    BTFG     10
# 12                  CLOSE OUTS PLUS   10004    CLSO     12
# 13         WESTERN ENERGY RESOURCES   10005    WERC     13
# 15                 A C F INDUSTRIES   10006     NaN     15
# 16                        SHAREDATA   10007    SDIC     16
# 17                        SHAREDATA   10007   SDICV     17
# 18                        SHAREDATA   10007   SDICE     18
# ...

# %%
for i in inc0['range']:
    inc0.COMNAM[i] = inc0.COMNAM[i].replace(" INC","")
# Out:
# /Users/michaelwymbs/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
crsptblout = crsptbl.drop(['familyname','Unnamed: 0','PERMNO'],1)

# %%
CRSPoutput = pd.merge(crsptblout, dictionarydf, left_on='range', right_on='range',how='left');

# %%
CRSPoutput.to_csv('CRSPniave.csv')

# %%
j=0
for i in range(0,dictionarydf.shape[0]): 
    if len(dictionarydf.PERMNO[i])>5:
        j=j+1
j
# Out:
# 26

# %%
dictionarydf.shape
# Out:
# (4295, 2)

# %%
dictionarydf.shape[0]
